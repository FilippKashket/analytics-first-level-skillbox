# %%
import pandas as pd

df_courses = pd.read_csv('data/courses.csv')
df_course_contents = pd.read_csv('data/course_contents.csv')
df_progresses = pd.read_csv('data/progresses.csv')
df_progress_phases = pd.read_csv('data/progress_phases.csv')
df_students = pd.read_csv('data/students.csv')

# %%
# джойним датасеты так, чтобы было название курса, а не только айди
course_contents = df_course_contents.join(df_courses.set_index('id'), on='course_id')

# оставим нужные нам колонки
course_contents = course_contents[['title','module_number','lesson_number','module_title','lesson_title','is_homework']]

# выбираем модули, в которых есть домашняя работа
course_contents_hw = course_contents[course_contents['is_homework']==True]

# смотрим, где у нас ‘count’ в группировке будет больше единицы
course_contents_hw[course_contents_hw.groupby(['title','module_number'])['lesson_number'].transform('count') > 1]
# Out:
#                        title  module_number  lesson_number  \
# 457  Java-разработчик c нуля              4              6
# 464  Java-разработчик c нуля              4             13
# 468  Java-разработчик c нуля              4             17
# 472  Java-разработчик c нуля              4             21
# 476  Java-разработчик c нуля              4             25
# 478  Java-разработчик c нуля              4             27
# 483  Java-разработчик c нуля              5              5
# 485  Java-разработчик c нуля              5              7
# 487  Java-разработчик c нуля              5              9
# 489  Java-разработчик c нуля              5             11
# 491  Java-разработчик c нуля              5             13
# 493  Java-разработчик c нуля              6              2
# 495  Java-разработчик c нуля              6              4
# 497  Java-разработчик c нуля              6              6
# 504  Java-разработчик c нуля              6             13
# 506  Java-разработчик c нуля              7              2
# 512  Java-разработчик c нуля              7              8
# 521  Java-разработчик c нуля              8              4
# 525  Java-разработчик c нуля              8              8
# 528  Java-разработчик c нуля              8             11
# 533  Java-разработчик c нуля              9              5
# 535  Java-разработчик c нуля              9              7
# 537  Java-разработчик c нуля              9              9
# 540  Java-разработчик c нуля              9             12
# 542  Java-разработчик c нуля              9             14
# 833       Веб-дизайн PRO 2.0              4              3
# 835       Веб-дизайн PRO 2.0              4              5
# 972                UX-дизайн              9              7
# 973                UX-дизайн              9              8
#
#                                          module_title  \
# 457                              Числа, строки и даты
# 464                              Числа, строки и даты
# 468                              Числа, строки и даты
# 472                              Числа, строки и даты
# 476                              Числа, строки и даты
# 478                              Числа, строки и даты
# 483                               Массивы и коллекции
# 485                               Массивы и коллекции
# 487                               Массивы и коллекции
# 489                               Массивы и коллекции
# 491                               Массивы и коллекции
# 493                        Наследование и полиморфизм
# 495                        Наследование и полиморфизм
# 497                        Наследование и полиморфизм
# 504                        Наследование и полиморфизм
# 506                            Особенности ООП в Java
# 512                            Особенности ООП в Java
# 521  Исключения, отладка, тестирование и логгирование
# 525  Исключения, отладка, тестирование и логгирование
# 528  Исключения, отладка, тестирование и логгирование
# 533                          Работа с файлами и сетью
# 535                          Работа с файлами и сетью
# 537                          Работа с файлами и сетью
# 540                          Работа с файлами и сетью
# 542                          Работа с файлами и сетью
# 833                                     Введение в UX
# 835                                     Введение в UX
# 972              Concept design: творчество в дизайне
# 973              Concept design: творчество в дизайне
#
#                        lesson_title  is_homework
# 457             Домашняя работа 4.1         True
# 464             Домашняя работа 4.2         True
# 468             Домашняя работа 4.3         True
# 472             Домашняя работа 4.4         True
# 476             Домашняя работа 4.5         True
# 478             Домашняя работа 4.6         True
# 483             Домашняя работа 5.1         True
# 485             Домашняя работа 5.2         True
# 487             Домашняя работа 5.3         True
# 489             Домашняя работа 5.4         True
# 491             Домашняя работа 5.5         True
# 493                 Домашняя работа         True
# 495                 Домашняя работа         True
# 497                 Домашняя работа         True
# 504                 Домашняя работа         True
# 506                 Домашняя работа         True
# 512                 Домашняя работа         True
# 521                 Домашняя работа         True
# 525                 Домашняя работа         True
# 528                 Домашняя работа         True
# 533                 Домашняя работа         True
# 535                 Домашняя работа         True
# 537                 Домашняя работа         True
# 540                 Домашняя работа         True
# 542                 Домашняя работа         True
# 833             Домашнее задание #1         True
# 835             Домашнее задание #2         True
# 972  Домашняя работа (первая часть)         True
# 973  Домашняя работа (вторая часть)         True
