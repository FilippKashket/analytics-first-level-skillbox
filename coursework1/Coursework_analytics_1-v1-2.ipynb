# %% [markdown]
# # Курсовая работа. Блок 1
# *Pandas и Matplotlib*
#
# **NB!** Код должен быть с комментариями к каждому логическому блоку кода. В противном случае работа **не** будет принята. <br><br>
# Выполнение курсовой работы может потребовать использование дополнительных библиотек.
#
# <br><br>
# **Описание работы:**
#
# Перед вами стоит бизнес-задача – на основании имеющихся данных подготовить аналитический отчет, который в дальнейшем поможет продюсерам образовательных программ эффективно выстраивать стратегию по модернизированию и улучшению курсов. В начале отчета предлагается оформить емкий описательный блок по каждому курсу на основании рассчитанных показателей. Далее предлагается посчитать потенциальную нагрузку на преподавателей, чтобы оценить необходимость расширения штата сотрудников. Затем идет блок из двух пунктов по анализу качества контента курсов, где необходимо выявить проблемные модули, которые, возможно, требуют доработки. Также стоит задача выявить потенциальную сезонность. Наконец, предложено задание для самостоятельной разработки метрики успеваемости студентов для нахождения тех, кто значительно хуже справляются с прохождением курса. Каждый из пунктов анализа предполагается сопроводить аналитическим выводом на основании рассчитанных метрик.
#
# <br><br>
#
# _________
# Обозначения:<br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(p)** – задание может быть выполнено после прохождения модулей по Pandas <br>
# &nbsp;&nbsp;&nbsp;&nbsp;**(m)** – задание может быть выполнено после прохождения модуля по Matplotlib <br>
# &nbsp;&nbsp;&nbsp;&nbsp;⭐ – необязательное задание повышенной сложности
# _________
#
# [Codebook](#Codebook) <br>
# [1. Описание и начальная работа с данными](#1.1-Описание-и-начальная-работа-с-данными)<br>
# [2. Расчет потенциальной нагрузки на преподавателей](#2.-Расчет-потенциальной-нагрузки-на-преподавателей)<br>
# [3. Выявление проблемных модулей](#3.-Выявление-проблемных-модулей)<br>
# [4. Расчет конверсии](#4.-Расчет-конверсии) <br>
# [5. Метрика успеваемости ](#5.-Метрика-успеваемости)

# %% [markdown]
# ## Codebook
#
# `courses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `title` – название курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `field` – сфера, к которой относится курс <br> <br><br>
# `students.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `city` – город студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `birthday` – день рождения студента <br> <br><br>
# `course_contents.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `course_id` – идентификатор курса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `module_title` – название модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_title` – название урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `lesson_token` – токен урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `is_video` – наличие видео *(true/false)* <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `is_homework` – наличие домашней работы *(true/false)* <br>
# <br><br>
# `progresses.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `student_id` – идентификатор студента <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `course_id` – идентификатор курса <br> <br><br>
# `progress_phases.csv` содержит следующие значения: <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp; `progress_id` – идентификатор прогресса <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `module_number` – номер модуля <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `lesson_number` – номер урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `status` – статус прохождения урока <br>
# &nbsp;&nbsp;&nbsp;&nbsp;  `start_date` – дата начала <br>
# &nbsp;&nbsp;&nbsp;&nbsp; `finish_date` – дата окончания <br>
# <br><br>

# %% [markdown]
# ## 1. Описание и начальная работа с данными
#
# Вам необходимо подготовить данные и описать их. Данные реальные и содержат пропущенные значения, а также лишние относительно друг друга данные. <br>
#
# Объедините датасеты (кроме `students.scv`) в один общий для дальнейшей работы. Отдельный датасет создайте для расчета среднего возраста студентов курсов (отдельный датасет со `students.scv` нужен, чтобы в основном не потерять значения в основном датасете из-за того, что не по всем студентам есть анкетные данные о дате рождения). <br> <br>
# Опишите данные: <br>
# 1. **(p)** Посчитайте
#       * общее количество курсов в датасете,
#       * количество модулей на каждом курсе,
#       * количество уроков в каждом модуле на каждом курсе,
#       * медианное количество уроков в модуле на каждом курсе,
#       * количество учеников на каждом курсе
#       * минимальный, максимальный, средний, медианный возраст студентов
#       * минимальный, максимальный, средний, медианный возраст студентов на каждом курсе
# 2. **(m)** Постройте bar-chart, отражающий количество студентов на каждом курсе. Ticks нужно развернуть так, чтобы они были читаемы
# 3. **(m)** Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий количество студентов на каждом курсе. График должен иметь заголовок. Значения должны быть отсортированы. Цвет столбцов должен содержать информацию о сфере, к которой относится курс (то есть нужна легенда). Прозрачность должна стоять на отметке 0.1. На график должна быть нанесена линия медианы. У медианы должен быть свой цвет. Рамки у графика быть не должно ⭐
# 4.     На основании рассчитанных значений опишите данные (описание должно быть полным и покрывать все полученные выше метрики)
#
# _____________________________________________________________________

# %% [markdown]
# Для того, чтобы проверить, что вы правильно соединили все датасеты в основной (без `students.csv`), запустите аналогичный приведенному ниже запрос. Выдача должна совпадать. Имейте в виду, что названия некоторых столбцов были переименованы.

# %%
main[main.student_id == '768c2987a744c51ce64a5993a2a94eaf'] # проверка основного датасета
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fa7c70b92776> in <module>
# ----> 1 main[main.student_id == '768c2987a744c51ce64a5993a2a94eaf'] # проверка основного датасета
#
# NameError: name 'main' is not defined

# %%
import pandas as pd

df_students = pd.read_csv("./data/students.csv");
df_students_avg_age = pd.read_csv("./data/students.csv");

df_progress_phases = pd.read_csv("./data/progress_phases.csv")
df_progresses = pd.read_csv("./data/progresses.csv")
df_courses = pd.read_csv("./data/courses.csv", names=['del', 'course_id_del', 'course_title', 'course_field'])
df_course_contents = pd.read_csv("./data/course_contents.csv")

df_courses = df_courses.drop("del", 1)

df_main = df_progress_phases.merge(df_progresses, left_on="progress_id", right_on="id").drop("id",1)
df_main = df_main.merge(df_courses, left_on="course_id", right_on="course_id_del").drop("course_id_del",1)
df_main = df_main.merge(df_course_contents, on=['course_id', 'module_number', 'lesson_number'])

df_students_courses = df_students.merge(df_progresses, left_on='id', right_on='student_id')
df_students_courses = df_students_courses.merge(df_courses, left_on='course_id', right_on='course_id_del')

df_main[df_main.student_id == '768c2987a744c51ce64a5993a2a94eaf']

df_copy = df_main[(df_main['course_id']=='ac634845fb0350d0e9d49078aaa4b68f')]

df_copy['start_date'] =df_copy['start_date'].apply(lambda date: datetime.datetime.strptime(date[0:7], '%Y-%m'))


df_copy.to_csv('./data/df_main_11122019.csv', sep=";")
# Out:
# C:\Users\FilippKashket\Anaconda3\lib\site-packages\ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
print('Общее количество курсов в датасете:', len(df_main.groupby("course_id")))
# Out:
# Общее количество курсов в датасете: 15

# %%
print('Количество модулей на каждом курсе')
df_courses_list = df_main.groupby(["course_id", "course_title"])['module_number'].nunique()
df_courses_list
# Out:
# Количество модулей на каждом курсе
# course_id                         course_title
# 04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов                   21
# 0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов          17
# 17013cd19d25cb3f28dc1b2683721bb9  Веб-дизайн Базовый                     17
# 480d25ad36878fce09e7aada316ba1a6  Веб-разработчик                        20
# 6e4837f0a65c68efbfdd0594d6774701  Java-разработчик                       17
# 842218e7c983795934bbe4533c0888c8  SMM-маркетолог от А до Я               11
# 943306102e5b067d08a29094f37b8193  Java-разработчик c нуля                 9
# abce125a877c2196a3bc7bfbc11b5fc5  Веб-вёрстка для начинающих 2.0          8
# ac634845fb0350d0e9d49078aaa4b68f  Excel Базовый                           9
# bf27a4bf4ada4c756451703ea62a914f  Интернет-маркетолог от Ingate          18
# c9fcb746d51e41bc5a217002d081454b  Веб-дизайн PRO 2.0                     17
# ccbab00e99b27f83369d6cc89d914ad6  PHP-разработчик с 0 до PRO. Часть 1     8
# dad6f6ffc086caa89e2f40c28a9c7490  UX-дизайн                              20
# e3a0df907589d56692b5cb561fd90d87  Веб-дизайн с нуля 2.0                  19
# e9bb9205eeed307ee7cbaa08bfd166c3  JavaScript с нуля                      18
# Name: module_number, dtype: int64

# %%
print('количество уроков в каждом модуле на каждом курсе')

df_lesson_number=df_main.groupby(["course_id", "course_title", 'module_number'])['lesson_number'].nunique().reset_index()
df_lesson_number
# Out:
# количество уроков в каждом модуле на каждом курсе
#                             course_id                   course_title  \
# 0    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 1    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 2    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 3    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 4    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 5    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 6    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 7    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 8    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 9    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 10   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 11   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 12   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 13   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 14   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 15   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 16   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 17   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 18   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 19   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 20   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 21   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 22   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 23   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 24   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 25   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 26   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 27   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 28   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 29   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# ..                                ...                            ...
# 199  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 200  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 201  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 202  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 203  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 204  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 205  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 206  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 207  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 208  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 209  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 210  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 211  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 212  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 213  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 214  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 215  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 216  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 217  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 218  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 219  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 220  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 221  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 222  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 223  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 224  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 225  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 226  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 227  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 228  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
#
#      module_number  lesson_number
# 0                1              3
# 1                2              3
# 2                3              4
# 3                4              4
# 4                5              4
# 5                6              1
# 6                7              3
# 7                8              3
# 8                9              1
# 9               10              7
# 10              11              3
# 11              12              6
# 12              13              5
# 13              14              4
# 14              15              4
# 15              16              1
# 16              17              1
# 17              18              3
# 18              19              1
# 19              20              1
# 20              21              1
# 21               1              4
# 22               2              3
# 23               3              4
# 24               4              3
# 25               5              4
# 26               6              5
# 27               7              6
# 28               8             12
# 29               9              4
# ..             ...            ...
# 199              8              1
# 200              9              3
# 201             10              5
# 202             11              4
# 203             12              5
# 204             13              6
# 205             14              5
# 206             15              4
# 207             16              4
# 208             17              5
# 209             18              4
# 210             19              4
# 211              1              7
# 212              2             12
# 213              3              8
# 214              4              9
# 215              5              5
# 216              6              4
# 217              7              5
# 218              8              7
# 219              9              8
# 220             10              9
# 221             11              6
# 222             12              7
# 223             13              9
# 224             14              6
# 225             15              6
# 226             16              7
# 227             17              3
# 228             18              1
#
# [229 rows x 4 columns]

# %%
print('медианное количество уроков в модуле на каждом курсе')
df_lesson_number.groupby(["course_id","course_title"])['lesson_number'].median()
# Out:
# медианное количество уроков в модуле на каждом курсе
# course_id                         course_title
# 04ba6d0b40670c43a209141fa01fa784  Анимация интерфейсов                    3.0
# 0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов           5.0
# 17013cd19d25cb3f28dc1b2683721bb9  Веб-дизайн Базовый                      3.0
# 480d25ad36878fce09e7aada316ba1a6  Веб-разработчик                         2.0
# 6e4837f0a65c68efbfdd0594d6774701  Java-разработчик                        7.0
# 842218e7c983795934bbe4533c0888c8  SMM-маркетолог от А до Я                6.0
# 943306102e5b067d08a29094f37b8193  Java-разработчик c нуля                13.0
# abce125a877c2196a3bc7bfbc11b5fc5  Веб-вёрстка для начинающих 2.0          7.0
# ac634845fb0350d0e9d49078aaa4b68f  Excel Базовый                           5.0
# bf27a4bf4ada4c756451703ea62a914f  Интернет-маркетолог от Ingate           6.5
# c9fcb746d51e41bc5a217002d081454b  Веб-дизайн PRO 2.0                      5.0
# ccbab00e99b27f83369d6cc89d914ad6  PHP-разработчик с 0 до PRO. Часть 1     4.0
# dad6f6ffc086caa89e2f40c28a9c7490  UX-дизайн                               3.5
# e3a0df907589d56692b5cb561fd90d87  Веб-дизайн с нуля 2.0                   4.0
# e9bb9205eeed307ee7cbaa08bfd166c3  JavaScript с нуля                       7.0
# Name: lesson_number, dtype: float64

# %%
print('количество учеников на каждом курс')
studentd_count = df_main.groupby(["course_id","course_title"])['student_id'].nunique().reset_index()
studentd_count.sort_values(by='student_id')
# Out:
# количество учеников на каждом курс
#                            course_id                         course_title  \
# 5   842218e7c983795934bbe4533c0888c8             SMM-маркетолог от А до Я
# 2   17013cd19d25cb3f28dc1b2683721bb9                   Веб-дизайн Базовый
# 6   943306102e5b067d08a29094f37b8193              Java-разработчик c нуля
# 0   04ba6d0b40670c43a209141fa01fa784                 Анимация интерфейсов
# 3   480d25ad36878fce09e7aada316ba1a6                      Веб-разработчик
# 1   0770b1b039964228294f1f34b29fc2c1        Руководитель digital-проектов
# 4   6e4837f0a65c68efbfdd0594d6774701                     Java-разработчик
# 8   ac634845fb0350d0e9d49078aaa4b68f                        Excel Базовый
# 11  ccbab00e99b27f83369d6cc89d914ad6  PHP-разработчик с 0 до PRO. Часть 1
# 14  e9bb9205eeed307ee7cbaa08bfd166c3                    JavaScript с нуля
# 12  dad6f6ffc086caa89e2f40c28a9c7490                            UX-дизайн
# 10  c9fcb746d51e41bc5a217002d081454b                   Веб-дизайн PRO 2.0
# 7   abce125a877c2196a3bc7bfbc11b5fc5       Веб-вёрстка для начинающих 2.0
# 13  e3a0df907589d56692b5cb561fd90d87                Веб-дизайн с нуля 2.0
# 9   bf27a4bf4ada4c756451703ea62a914f        Интернет-маркетолог от Ingate
#
#     student_id
# 5          506
# 2          518
# 6          581
# 0          598
# 3          628
# 1          685
# 4          763
# 8          782
# 11         854
# 14         966
# 12        1151
# 10        1711
# 7         2004
# 13        2014
# 9         2168

# %%
from datetime import date, timedelta

df_students_avg_age = pd.read_csv("./data/students.csv");
print('минимальный, максимальный, средний, медианный возраст студентов')

df_students_avg_age = df_students_avg_age.dropna()


df_students_avg_age['age'] = df_students_avg_age['birthday'].apply(lambda x: (date.today()- date.fromisoformat(x))// timedelta(days=365.2425)   )

df_students_avg_age =df_students_avg_age.drop(df_students_avg_age[df_students_avg_age.age<=2].index)
df_students_avg_age =df_students_avg_age.drop(df_students_avg_age[df_students_avg_age.age>=125].index)
df_students_avg_age['age'].agg(['min','max','mean','median'])
# Out:
# минимальный, максимальный, средний, медианный возраст студентов
# min         5.000000
# max       119.000000
# mean       29.199646
# median     28.000000
# Name: age, dtype: float64

# %%
print('минимальный, максимальный, средний, медианный возраст студентов на каждом курсе')

df_students_courses = df_students_courses[['course_id', 'course_title', 'student_id', 'birthday']].dropna()


df_students_courses['age'] = df_students_courses['birthday'].apply(lambda x: (date.today()- date.fromisoformat(x))// timedelta(days=365.2425)   )

df_students_courses =df_students_courses.drop(df_students_courses[df_students_courses.age<=7].index)

df_students_courses =df_students_courses.drop(df_students_courses[df_students_courses.age>=95].index)
df_students_courses.groupby(['course_id', 'course_title']).agg(['min','max','mean','median'])
# Out:
# минимальный, максимальный, средний, медианный возраст студентов на каждом курсе
#                                                                      age      \
#                                                                      min max
# course_id                        course_title
# 04ba6d0b40670c43a209141fa01fa784 Анимация интерфейсов                 14  50
# 0770b1b039964228294f1f34b29fc2c1 Руководитель digital-проектов        18  54
# 17013cd19d25cb3f28dc1b2683721bb9 Веб-дизайн Базовый                   15  50
# 480d25ad36878fce09e7aada316ba1a6 Веб-разработчик                      13  50
# 6e4837f0a65c68efbfdd0594d6774701 Java-разработчик                     14  64
# 842218e7c983795934bbe4533c0888c8 SMM-маркетолог от А до Я             16  51
# 943306102e5b067d08a29094f37b8193 Java-разработчик c нуля              13  54
# abce125a877c2196a3bc7bfbc11b5fc5 Веб-вёрстка для начинающих 2.0       13  58
# ac634845fb0350d0e9d49078aaa4b68f Excel Базовый                        16  60
# bf27a4bf4ada4c756451703ea62a914f Интернет-маркетолог от Ingate        16  89
# c9fcb746d51e41bc5a217002d081454b Веб-дизайн PRO 2.0                   14  58
# ccbab00e99b27f83369d6cc89d914ad6 PHP-разработчик с 0 до PRO. Часть 1  13  74
# dad6f6ffc086caa89e2f40c28a9c7490 UX-дизайн                            14  84
# e3a0df907589d56692b5cb561fd90d87 Веб-дизайн с нуля 2.0                13  75
# e9bb9205eeed307ee7cbaa08bfd166c3 JavaScript с нуля                    13  58
#
#                                                                                  \
#                                                                            mean
# course_id                        course_title
# 04ba6d0b40670c43a209141fa01fa784 Анимация интерфейсов                 29.148976
# 0770b1b039964228294f1f34b29fc2c1 Руководитель digital-проектов        31.091234
# 17013cd19d25cb3f28dc1b2683721bb9 Веб-дизайн Базовый                   28.117021
# 480d25ad36878fce09e7aada316ba1a6 Веб-разработчик                      27.673774
# 6e4837f0a65c68efbfdd0594d6774701 Java-разработчик                     28.861718
# 842218e7c983795934bbe4533c0888c8 SMM-маркетолог от А до Я             28.561368
# 943306102e5b067d08a29094f37b8193 Java-разработчик c нуля              29.062069
# abce125a877c2196a3bc7bfbc11b5fc5 Веб-вёрстка для начинающих 2.0       28.154155
# ac634845fb0350d0e9d49078aaa4b68f Excel Базовый                        33.169670
# bf27a4bf4ada4c756451703ea62a914f Интернет-маркетолог от Ingate        30.775806
# c9fcb746d51e41bc5a217002d081454b Веб-дизайн PRO 2.0                   27.998118
# ccbab00e99b27f83369d6cc89d914ad6 PHP-разработчик с 0 до PRO. Часть 1  29.043478
# dad6f6ffc086caa89e2f40c28a9c7490 UX-дизайн                            29.729188
# e3a0df907589d56692b5cb561fd90d87 Веб-дизайн с нуля 2.0                27.726702
# e9bb9205eeed307ee7cbaa08bfd166c3 JavaScript с нуля                    28.133479
#
#
#                                                                      median
# course_id                        course_title
# 04ba6d0b40670c43a209141fa01fa784 Анимация интерфейсов                    29
# 0770b1b039964228294f1f34b29fc2c1 Руководитель digital-проектов           31
# 17013cd19d25cb3f28dc1b2683721bb9 Веб-дизайн Базовый                      27
# 480d25ad36878fce09e7aada316ba1a6 Веб-разработчик                         27
# 6e4837f0a65c68efbfdd0594d6774701 Java-разработчик                        28
# 842218e7c983795934bbe4533c0888c8 SMM-маркетолог от А до Я                28
# 943306102e5b067d08a29094f37b8193 Java-разработчик c нуля                 28
# abce125a877c2196a3bc7bfbc11b5fc5 Веб-вёрстка для начинающих 2.0          27
# ac634845fb0350d0e9d49078aaa4b68f Excel Базовый                           33
# bf27a4bf4ada4c756451703ea62a914f Интернет-маркетолог от Ingate           30
# c9fcb746d51e41bc5a217002d081454b Веб-дизайн PRO 2.0                      27
# ccbab00e99b27f83369d6cc89d914ad6 PHP-разработчик с 0 до PRO. Часть 1     28
# dad6f6ffc086caa89e2f40c28a9c7490 UX-дизайн                               29
# e3a0df907589d56692b5cb561fd90d87 Веб-дизайн с нуля 2.0                   27
# e9bb9205eeed307ee7cbaa08bfd166c3 JavaScript с нуля                       27

# %%
import matplotlib.pyplot as plt

fig, subplot = plt.subplots()
fig.set_size_inches(18.5, 10.5, forward=True)

subplot.bar(studentd_count['course_title'],
          studentd_count['student_id']) 

plt.xticks(rotation=90)
plt.show()

# %%
def chose_color(x):
    if x=='Development':
        return 'r'
    elif x=='Design':
        return'b'
    elif x=='Marketing':
        return 'g'
    elif x=='Business':
        return 'y'

import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
                                                                    
studentd_count_sorted = df_main.groupby(["course_id","course_title","course_field"])['student_id'].nunique().reset_index()

studentd_count_sorted = studentd_count_sorted.sort_values(by='student_id')

studentd_count_sorted['color'] = studentd_count_sorted["course_field"].apply(chose_color)

fig, subplot = plt.subplots()
fig.set_size_inches(18.5, 10.5, forward=True)

subplot.barh(studentd_count_sorted['course_title'],
          studentd_count_sorted['student_id'], alpha=0.1, color=studentd_count_sorted['color'])

subplot.set_title('Количество студентов на каждом курсе')

subplot.axvline(studentd_count_sorted['student_id'].mean(), color='m', linewidth=2)

subplot.spines['top'].set_visible(False)
subplot.spines['right'].set_visible(False)


patches =[]

patches.append(mpatches.Patch(color='r', label='Development', alpha=0.1))
patches.append(mpatches.Patch(color='b', label='Design', alpha=0.1))
patches.append( mpatches.Patch(color='g', label='Marketing', alpha=0.1))
patches.append( mpatches.Patch(color='y', label='Business', alpha=0.1))

plt.legend(handles=patches, fontsize = 'x-large')

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## Выводы по первому блоку
# 1. Три самых популярных курса
#     * Веб-вёрстка для начинающих 2.0         2004
#     * Интернет-маркетолог от Ingate          2168
#     * Веб-дизайн с нуля 2.0                  2014
#
# В этих курсах различное количество модулей, и уроков в модулях. Поэтмоу популярность никак не связана со структурой и количесвом уроков.
#
# Два самых не популярных курса
#     * SMM-маркетолог от А до Я	506
#     * Веб-дизайн Базовый	518
#
# 2. Есть модули курсов в которых всего один урок, возможно стоит подумать над оптимизацией структуры таких курсов и обьединить несколькомодулей в один.
#
# 3. Средний возраст учеников курсов 28-29 лет.
#
# Предпочтений курсов в завсимости от возрастов не наблюдается.
# Разве что "Excel Базовый" выбирают люди более старшего возраста, если судить по медианному возрасту.
#
# 4. Если ориентироваться на средний и имедианный возраста, то можно сделать вывод, что типичный студент курсов - это работающий человек который или повышает квалификацию или переучивается на другую специальность.

# %% [markdown]
# ## 2. Расчет потенциальной нагрузки на преподавателей
#
# 1. **(p)** Рассчитать прирост студентов на каждом курсе в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно). Считать дату начала прохождения курса студентом по дате начала первой домашней работы.
# 2. **(m)** На основании первого пункта построить line-graph с приростом студентов в каждом месяце для каждого курса. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы.
# 3. **(m)** На основании первого пункта построить line-graph с несколькими линиями, отражающими прирост студентов в каждом месяце для каждого курса. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая прирост, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
# 4. **(p)** Рассчитать количество прогрессов по выполнению домашних работ в каждом месяце за всю историю (каждый месяц в диапазоне от марта 2016 до июля 2019 включительно) для каждого курса. Учитывать, что выполнение домашнего задания может перетекать из одного месяца в другой (такие дз надо включать в общее число прогрессов для всех месяцев, которые покрывает срок выполнения этих дз)
# 5. **(m)** Построить line-graph по четвертому пункту. 15 графиков. Графики должны иметь заголовки, оси должны быть подписаны. Ticks нужно развернуть так, чтобы они были читаемы
# 6. **(m)** Построить один line-graph для всех курсов по четвертому пункту. 15 линий на графике. Ticks нужно развернуть так, чтобы они были читаемы. График должен иметь заголовок. Ось, отражающая количество прогрессов, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно ⭐
# 7. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
import datetime


df_increase=df_main[['course_id','course_title', 'student_id', 'start_date', 'is_homework']]
df_increase = df_increase[(df_increase['is_homework']==True)]
df_increase['start_month'] =df_increase['start_date'].apply(lambda date: datetime.datetime.strptime(date[0:7], '%Y-%m'))

df_increase=df_increase.groupby(['course_id','course_title', 'student_id'])['start_month'].min().reset_index()

df_increase['dummy'] =1

df_increase = df_increase.groupby(['course_id','course_title','start_month'])['dummy'].sum().reset_index()
 
df_increase = df_increase.sort_values(by='start_month')

df_increase
# Out:
#                             course_id                         course_title  \
# 56   480d25ad36878fce09e7aada316ba1a6                      Веб-разработчик
# 191  dad6f6ffc086caa89e2f40c28a9c7490                            UX-дизайн
# 38   17013cd19d25cb3f28dc1b2683721bb9                   Веб-дизайн Базовый
# 192  dad6f6ffc086caa89e2f40c28a9c7490                            UX-дизайн
# 57   480d25ad36878fce09e7aada316ba1a6                      Веб-разработчик
# 193  dad6f6ffc086caa89e2f40c28a9c7490                            UX-дизайн
# 18   0770b1b039964228294f1f34b29fc2c1        Руководитель digital-проектов
# 19   0770b1b039964228294f1f34b29fc2c1        Руководитель digital-проектов
# 194  dad6f6ffc086caa89e2f40c28a9c7490                            UX-дизайн
# 58   480d25ad36878fce09e7aada316ba1a6                      Веб-разработчик
# 141  bf27a4bf4ada4c756451703ea62a914f        Интернет-маркетолог от Ingate
# 59   480d25ad36878fce09e7aada316ba1a6                      Веб-разработчик
# 77   6e4837f0a65c68efbfdd0594d6774701                     Java-разработчик
# 39   17013cd19d25cb3f28dc1b2683721bb9                   Веб-дизайн Базовый
# 60   480d25ad36878fce09e7aada316ba1a6                      Веб-разработчик
# 78   6e4837f0a65c68efbfdd0594d6774701                     Java-разработчик
# 20   0770b1b039964228294f1f34b29fc2c1        Руководитель digital-проектов
# 142  bf27a4bf4ada4c756451703ea62a914f        Интернет-маркетолог от Ingate
# 0    04ba6d0b40670c43a209141fa01fa784                 Анимация интерфейсов
# 195  dad6f6ffc086caa89e2f40c28a9c7490                            UX-дизайн
# 124  ac634845fb0350d0e9d49078aaa4b68f                        Excel Базовый
# 1    04ba6d0b40670c43a209141fa01fa784                 Анимация интерфейсов
# 227  e9bb9205eeed307ee7cbaa08bfd166c3                    JavaScript с нуля
# 40   17013cd19d25cb3f28dc1b2683721bb9                   Веб-дизайн Базовый
# 61   480d25ad36878fce09e7aada316ba1a6                      Веб-разработчик
# 174  ccbab00e99b27f83369d6cc89d914ad6  PHP-разработчик с 0 до PRO. Часть 1
# 125  ac634845fb0350d0e9d49078aaa4b68f                        Excel Базовый
# 143  bf27a4bf4ada4c756451703ea62a914f        Интернет-маркетолог от Ingate
# 196  dad6f6ffc086caa89e2f40c28a9c7490                            UX-дизайн
# 79   6e4837f0a65c68efbfdd0594d6774701                     Java-разработчик
# ..                                ...                                  ...
# 108  943306102e5b067d08a29094f37b8193              Java-разработчик c нуля
# 189  ccbab00e99b27f83369d6cc89d914ad6  PHP-разработчик с 0 до PRO. Часть 1
# 94   6e4837f0a65c68efbfdd0594d6774701                     Java-разработчик
# 225  e3a0df907589d56692b5cb561fd90d87                Веб-дизайн с нуля 2.0
# 104  842218e7c983795934bbe4533c0888c8             SMM-маркетолог от А до Я
# 109  943306102e5b067d08a29094f37b8193              Java-разработчик c нуля
# 36   0770b1b039964228294f1f34b29fc2c1        Руководитель digital-проектов
# 242  e9bb9205eeed307ee7cbaa08bfd166c3                    JavaScript с нуля
# 122  abce125a877c2196a3bc7bfbc11b5fc5       Веб-вёрстка для начинающих 2.0
# 139  ac634845fb0350d0e9d49078aaa4b68f                        Excel Базовый
# 211  dad6f6ffc086caa89e2f40c28a9c7490                            UX-дизайн
# 158  bf27a4bf4ada4c756451703ea62a914f        Интернет-маркетолог от Ingate
# 16   04ba6d0b40670c43a209141fa01fa784                 Анимация интерфейсов
# 172  c9fcb746d51e41bc5a217002d081454b                   Веб-дизайн PRO 2.0
# 75   480d25ad36878fce09e7aada316ba1a6                      Веб-разработчик
# 17   04ba6d0b40670c43a209141fa01fa784                 Анимация интерфейсов
# 55   17013cd19d25cb3f28dc1b2683721bb9                   Веб-дизайн Базовый
# 37   0770b1b039964228294f1f34b29fc2c1        Руководитель digital-проектов
# 105  842218e7c983795934bbe4533c0888c8             SMM-маркетолог от А до Я
# 95   6e4837f0a65c68efbfdd0594d6774701                     Java-разработчик
# 226  e3a0df907589d56692b5cb561fd90d87                Веб-дизайн с нуля 2.0
# 190  ccbab00e99b27f83369d6cc89d914ad6  PHP-разработчик с 0 до PRO. Часть 1
# 110  943306102e5b067d08a29094f37b8193              Java-разработчик c нуля
# 123  abce125a877c2196a3bc7bfbc11b5fc5       Веб-вёрстка для начинающих 2.0
# 140  ac634845fb0350d0e9d49078aaa4b68f                        Excel Базовый
# 212  dad6f6ffc086caa89e2f40c28a9c7490                            UX-дизайн
# 159  bf27a4bf4ada4c756451703ea62a914f        Интернет-маркетолог от Ingate
# 173  c9fcb746d51e41bc5a217002d081454b                   Веб-дизайн PRO 2.0
# 76   480d25ad36878fce09e7aada316ba1a6                      Веб-разработчик
# 243  e9bb9205eeed307ee7cbaa08bfd166c3                    JavaScript с нуля
#
#     start_month  dummy
# 56   2016-03-01      1
# 191  2016-11-01      2
# 38   2017-03-01      2
# 192  2017-04-01      1
# 57   2017-04-01      1
# 193  2017-05-01      1
# 18   2017-05-01      1
# 19   2017-06-01      1
# 194  2017-06-01      1
# 58   2017-07-01      1
# 141  2018-01-01      1
# 59   2018-01-01      2
# 77   2018-01-01      1
# 39   2018-02-01     56
# 60   2018-02-01     30
# 78   2018-02-01     14
# 20   2018-02-01     66
# 142  2018-02-01     76
# 0    2018-02-01     15
# 195  2018-02-01     61
# 124  2018-02-01      6
# 1    2018-03-01     15
# 227  2018-03-01      6
# 40   2018-03-01     57
# 61   2018-03-01     47
# 174  2018-03-01      3
# 125  2018-03-01      3
# 143  2018-03-01     94
# 196  2018-03-01     61
# 79   2018-03-01     26
# ..          ...    ...
# 108  2019-05-01     74
# 189  2019-06-01     29
# 94   2019-06-01      5
# 225  2019-06-01     89
# 104  2019-06-01     67
# 109  2019-06-01     98
# 36   2019-06-01     15
# 242  2019-06-01     34
# 122  2019-06-01     89
# 139  2019-06-01     43
# 211  2019-06-01     48
# 158  2019-06-01    114
# 16   2019-06-01     14
# 172  2019-06-01     47
# 75   2019-06-01      3
# 17   2019-07-01      7
# 55   2019-07-01      2
# 37   2019-07-01     20
# 105  2019-07-01     46
# 95   2019-07-01      2
# 226  2019-07-01     76
# 190  2019-07-01     15
# 110  2019-07-01     63
# 123  2019-07-01     72
# 140  2019-07-01     28
# 212  2019-07-01     18
# 159  2019-07-01     91
# 173  2019-07-01     40
# 76   2019-07-01      4
# 243  2019-07-01     21
#
# [244 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

courses_list = df_increase.groupby(['course_title', 'course_id'])['dummy'].sum().reset_index()

for index, row in courses_list.iterrows():
    fig, subplot = plt.subplots()
    fig.set_size_inches(9, 5, forward=True)
    course_data = df_increase[(df_increase['course_id']==row.course_id)]
    
    start_date = course_data['start_month'].min()
    end_date = course_data['start_month'].max()
    
    m = pd.date_range(start_date, end_date, freq='MS')
    
    for month in m:
        if(course_data[(course_data['start_month']==month)]['start_month'].size==0):
            course_data.loc[month]= [row.course_id,row.course_title,month, 0]
    
    course_data = course_data.sort_values(by='start_month')
    subplot.set_title(row.course_title)
    subplot.plot(course_data['start_month'], course_data['dummy'])
    
    subplot.xaxis.set_ticks(m.values)
    
    subplot.set_ylabel('Число новых струдентов')
    subplot.set_xlabel('месяц')
    plt.xticks(rotation='vertical')

plt.show()
# Out:
# C:\Users\FilippKashket\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\FilippKashket\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\FilippKashket\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\FilippKashket\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\FilippKashket\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

courses_list = df_increase.groupby(['course_title', 'course_id'])['dummy'].sum().reset_index()
 
start_date = datetime.datetime.strptime("2016-03", '%Y-%m')
end_date = datetime.datetime.strptime("2019-07", '%Y-%m')
  
m = pd.date_range(start_date, end_date, freq='MS')

fig, subplot = plt.subplots()
fig.set_size_inches(18.5, 10.5, forward=True)
subplot.grid()
subplot.tick_params(labelbottom = True)
subplot.minorticks_on()

for index, row in courses_list.iterrows(): 
    course_data = df_increase[(df_increase['course_id']==row.course_id)]
    start_date = course_data['start_month'].min()
    end_date = course_data['start_month'].max()
    
    m_i = pd.date_range(start_date, end_date, freq='MS')
    for month in m_i:
        if(course_data[(course_data['start_month']==month)]['start_month'].size==0):
            course_data.loc[month]= [row.course_id,row.course_title,month, 0]
    course_data = course_data.sort_values(by='start_month')
    subplot.plot(course_data['start_month'], course_data['dummy'])

subplot.set_title('Прирост студентов по курсам')
subplot.spines['top'].set_visible(False)
subplot.spines['right'].set_visible(False)
subplot.set_ylabel('Число новых струдентов')
subplot.xaxis.set_ticks(m.values)
plt.legend(courses_list['course_title'])
plt.xticks(rotation='vertical')
plt.show()
# Out:
# C:\Users\FilippKashket\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\FilippKashket\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\FilippKashket\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\FilippKashket\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\FilippKashket\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
import datetime
import numpy as np

new_progress = []

df_courses_list = df_main.groupby(["course_id", "course_title"])['module_number'].nunique().reset_index()

df_progress1=df_main[['course_id','course_title', 'start_date', 'finish_date', 'is_homework']]
df_progress1 = df_progress1[(df_progress1['is_homework']==True)]

df_progress1['finish_date']=df_progress1['finish_date'].fillna(df_progress1['start_date'])

df_progress1['start_date']=df_progress1['start_date'].apply(lambda x: x[0:7])
df_progress1['finish_date']=df_progress1['finish_date'].apply(lambda x: x[0:7])
df_progress1['count'] = 1

df_progress1 = df_progress1.groupby(['course_id','course_title', 'start_date', 'finish_date']).sum().reset_index()

start_date = datetime.datetime.strptime("2016-03", '%Y-%m')
end_date = datetime.datetime.strptime("2019-07", '%Y-%m')

arr_coupses = df_courses_list[['course_id','course_title']].values

for index,item in enumerate(arr_coupses):
    for month in pd.date_range(start_date, end_date, freq='MS'):
        new_progress.append([item[0],item[1], month.date().strftime('%Y-%m')])

df_new_progress = pd.DataFrame(new_progress, columns=['course_id','course_title','date'])

df_new_progress.set_index(['course_id','date'], inplace=True)
df_new_progress['count'] = 0

for data in df_progress1.values:
    for month in pd.date_range(data[2], data[3], freq='MS'):    
        df_new_progress.loc[(data[0], month.date().strftime('%Y-%m')), 'count'] +=data[4]      

df_new_progress
# Out:
#                                                   course_title  count
# course_id                        date
# 04ba6d0b40670c43a209141fa01fa784 2016-03  Анимация интерфейсов    0.0
#                                  2016-04  Анимация интерфейсов    0.0
#                                  2016-05  Анимация интерфейсов    0.0
#                                  2016-06  Анимация интерфейсов    0.0
#                                  2016-07  Анимация интерфейсов    0.0
#                                  2016-08  Анимация интерфейсов    0.0
#                                  2016-09  Анимация интерфейсов    0.0
#                                  2016-10  Анимация интерфейсов    0.0
#                                  2016-11  Анимация интерфейсов    0.0
#                                  2016-12  Анимация интерфейсов    0.0
#                                  2017-01  Анимация интерфейсов    0.0
#                                  2017-02  Анимация интерфейсов    0.0
#                                  2017-03  Анимация интерфейсов    0.0
#                                  2017-04  Анимация интерфейсов    0.0
#                                  2017-05  Анимация интерфейсов    0.0
#                                  2017-06  Анимация интерфейсов    0.0
#                                  2017-07  Анимация интерфейсов    0.0
#                                  2017-08  Анимация интерфейсов    0.0
#                                  2017-09  Анимация интерфейсов    0.0
#                                  2017-10  Анимация интерфейсов    0.0
#                                  2017-11  Анимация интерфейсов    0.0
#                                  2017-12  Анимация интерфейсов    0.0
#                                  2018-01  Анимация интерфейсов    0.0
#                                  2018-02  Анимация интерфейсов   43.0
#                                  2018-03  Анимация интерфейсов   53.0
#                                  2018-04  Анимация интерфейсов   62.0
#                                  2018-05  Анимация интерфейсов   70.0
#                                  2018-06  Анимация интерфейсов  101.0
#                                  2018-07  Анимация интерфейсов  143.0
#                                  2018-08  Анимация интерфейсов  149.0
# ...                                                        ...    ...
# e9bb9205eeed307ee7cbaa08bfd166c3 2017-02     JavaScript с нуля    0.0
#                                  2017-03     JavaScript с нуля    0.0
#                                  2017-04     JavaScript с нуля    0.0
#                                  2017-05     JavaScript с нуля    0.0
#                                  2017-06     JavaScript с нуля    0.0
#                                  2017-07     JavaScript с нуля    0.0
#                                  2017-08     JavaScript с нуля    0.0
#                                  2017-09     JavaScript с нуля    0.0
#                                  2017-10     JavaScript с нуля    0.0
#                                  2017-11     JavaScript с нуля    0.0
#                                  2017-12     JavaScript с нуля    0.0
#                                  2018-01     JavaScript с нуля    0.0
#                                  2018-02     JavaScript с нуля    0.0
#                                  2018-03     JavaScript с нуля   12.0
#                                  2018-04     JavaScript с нуля   22.0
#                                  2018-05     JavaScript с нуля   36.0
#                                  2018-06     JavaScript с нуля   54.0
#                                  2018-07     JavaScript с нуля   99.0
#                                  2018-08     JavaScript с нуля  109.0
#                                  2018-09     JavaScript с нуля  115.0
#                                  2018-10     JavaScript с нуля  183.0
#                                  2018-11     JavaScript с нуля  202.0
#                                  2018-12     JavaScript с нуля  224.0
#                                  2019-01     JavaScript с нуля  355.0
#                                  2019-02     JavaScript с нуля  360.0
#                                  2019-03     JavaScript с нуля  381.0
#                                  2019-04     JavaScript с нуля  351.0
#                                  2019-05     JavaScript с нуля  368.0
#                                  2019-06     JavaScript с нуля  359.0
#                                  2019-07     JavaScript с нуля  183.0
#
# [615 rows x 2 columns]

# %%
df_new_progress.to_csv('./data/progress_new.csv')

# %%
import matplotlib.pyplot as plt

courses_list = df_main.groupby(["course_id", "course_title"])['module_number'].nunique().reset_index()
df_new_progress = df_new_progress.reset_index()
#ourses_list = df_increase.groupby(['course_title', 'course_id'])['dummy'].sum().reset_index()

for index, row in courses_list.iterrows():
    fig, subplot = plt.subplots()
    fig.set_size_inches(10.5,6.5 , forward=True)
    subplot.grid()
    course_data = df_new_progress[(df_new_progress['course_id'] == row.course_id)]
    subplot.set_title(row.course_title)
    subplot.plot(course_data['date'], course_data['count'])
    subplot.set_ylabel('Прогресс')
    subplot.set_xlabel('месяц')
    plt.xticks(rotation='vertical')

plt.show()

# %%
import matplotlib.pyplot as plt

courses_list = df_main.groupby(["course_id", "course_title"])['module_number'].nunique().reset_index()

fig, subplot = plt.subplots()
fig.set_size_inches(18.5, 10.5, forward=True)
subplot.grid()
for index, row in courses_list.iterrows():
    course_data = df_new_progress[(df_new_progress['course_id'] == row.course_id)] 
    
    subplot.plot(course_data['date'], course_data['count'])
plt.legend(courses_list['course_title'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Выводы по второму блоку
# 1. Самый большой приток новых студентов был "Веб верстка для начинающих" в июле 2018. Видимо была какая-то очень удачная презентация или рекламная акция, стоит узнать что это было и попробовать на других курсах. Так же был всплеск в декабре 2019. Наверное была какая-то распродажа или люди дарят курсы друг другу на новый год.
#
# 2. Прогресс выполнения заданий связан с приростом студентов. Т.е прогресс вырос в январе 2019го. Так же есть неольшие увеличесния прогресса в летнее время.
#
# 3. В курсе веб верстка для начинающих выл большой прирост студентов в июле 2018, а прогресс по этому курсу возрос. Возможно даннае о количестве студентов по этому курсу содержат ошибку

# %% [markdown]
# ## 3. Выявление проблемных модулей
#
# 1. **(p)** Рассчитать минимальное, максимальное, среднее, медианное время прохождения каждого модуля (разность между временем начала и окончания выполнения домашней работы) для каждого курса. Если домашних заданий в модуле несколько, то считать разность между временем начала выполнения первой домашней работы и временем окончания выполнения последней домашней работы в модуле
# 2. **(m)** На основании первого пункта построить line-graph с медианным временем прохождения каждого модуля для каждого курса. 15 графиков. Графики должны иметь заголовки
# 3. **(p)**  Чтобы выявить сезонность, посчитать медианное время выполнения домашней работы по месяцам (12 месяцев, январь-декабрь) для каждого курса.
# 4. **(m)** На основании третьего пункта построить line-graph, на который будут нанесены линии для каждого курса с медианным временем выполнения домашней работы по месяцам. 15 линий на графике. График должен иметь заголовок. Ось, отражающая время прохождения, должна быть подписана. Линия для каждого курса должна иметь свой цвет (нужна легенда). Рамок у графика быть не должно  ⭐
# 5. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
import pandas as pd

df_main_1 = df_main.copy()

df_main_1 = df_main_1.dropna()
df_main_1['start_date'] = pd.to_datetime(df_main_1['start_date'])
df_main_1['finish_date'] = pd.to_datetime(df_main_1['finish_date'])

df_main_1 = df_main_1[(df_main_1['finish_date'] > df_main_1['start_date'])]

df_result = df_main_1.groupby(['course_id', 'course_title', 'module_number','progress_id']).agg({'start_date': 'min', 'finish_date':'max'}).reset_index()
df_result['difference'] = (df_result['finish_date'] - df_result['start_date']).dt.total_seconds()
df_result = df_result.groupby(['course_id', 'course_title', 'module_number'])['difference'].agg({'min','max','median','mean'}).reset_index()

df_result
# Out:
#                             course_id                   course_title  \
# 0    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 1    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 2    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 3    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 4    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 5    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 6    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 7    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 8    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 9    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 10   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 11   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 12   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 13   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 14   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 15   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 16   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 17   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 18   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 19   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 20   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 21   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 22   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 23   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 24   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 25   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 26   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 27   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 28   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 29   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# ..                                ...                            ...
# 199  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 200  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 201  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 202  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 203  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 204  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 205  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 206  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 207  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 208  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 209  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 210  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 211  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 212  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 213  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 214  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 215  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 216  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 217  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 218  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 219  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 220  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 221  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 222  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 223  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 224  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 225  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 226  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 227  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 228  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
#
#      module_number           max            min        median          mean
# 0                1  3.111311e+07       0.488768  1.595606e+06  5.770623e+06
# 1                2  3.150425e+07       0.603105  4.625997e+05  1.716272e+06
# 2                3  2.922445e+07       0.473754  7.705331e+05  2.962339e+06
# 3                4  3.927719e+07       0.066490  1.058600e+06  2.975003e+06
# 4                5  1.458422e+07       0.536897  9.764696e+05  2.021985e+06
# 5                6  1.373064e+07       1.642271  3.388980e+04  1.552587e+06
# 6                7  1.454452e+07       0.623322  1.187682e+06  2.224402e+06
# 7                8  3.429914e+07       0.509742  1.246727e+06  2.877400e+06
# 8                9  2.233920e+07       8.891490  1.590169e+05  2.428541e+06
# 9               10  1.432367e+07       0.532631  1.175320e+06  2.611255e+06
# 10              11  1.084960e+07       0.564967  1.121795e+06  2.110477e+06
# 11              12  1.373064e+07       0.264626  2.475636e+05  1.683681e+06
# 12              13  2.708736e+07       0.497337  9.893004e+05  2.031139e+06
# 13              14  2.902738e+07       0.576900  7.205435e+05  2.541251e+06
# 14              15  2.964804e+07       0.540861  8.888441e+05  2.523104e+06
# 15              16  4.845248e+06       3.814760  8.203695e+04  7.738471e+05
# 16              17  8.384805e+06      11.350909  6.326692e+04  6.924675e+05
# 17              18  9.888188e+06       0.608494  8.074122e+05  1.913567e+06
# 18              19  5.884158e+06       0.002733  5.530788e+03  4.621537e+05
# 19              20  5.762901e+06       1.317076  7.946871e+04  4.401505e+05
# 20              21  5.541384e+06  602665.208372  3.497848e+06  3.567838e+06
# 21               1  4.016629e+07       0.020434  6.652332e+05  2.006978e+06
# 22               2  3.546655e+07       5.720836  1.014242e+06  2.711640e+06
# 23               3  3.432736e+07      22.265840  1.260193e+06  2.658798e+06
# 24               4  3.998776e+07       0.814556  1.794588e+06  3.600796e+06
# 25               5  3.488855e+07       0.633319  1.181587e+06  3.478906e+06
# 26               6  3.488256e+07       0.692761  8.757823e+05  2.091622e+06
# 27               7  3.955620e+07       0.810710  1.196377e+06  2.828817e+06
# 28               8  3.999241e+07       0.760038  1.462084e+06  3.637619e+06
# 29               9  2.218420e+07       0.585684  8.556297e+05  2.034486e+06
# ..             ...           ...            ...           ...           ...
# 199              8  2.171331e+07       0.716863  1.048433e+04  1.017928e+06
# 200              9  2.816468e+07       1.902905  8.735823e+05  1.548700e+06
# 201             10  2.197049e+07       7.970898  9.737225e+05  1.805116e+06
# 202             11  2.192974e+07       2.513022  1.041102e+06  1.787285e+06
# 203             12  1.733924e+07       6.964934  7.893277e+05  1.373578e+06
# 204             13  1.749524e+07      18.417901  6.504990e+05  1.131051e+06
# 205             14  1.730161e+07      17.517060  5.580322e+05  1.052871e+06
# 206             15  2.024744e+07       3.367706  8.808030e+05  1.489171e+06
# 207             16  1.047388e+07     194.583190  6.160916e+05  1.168845e+06
# 208             17  1.357121e+07     124.004309  4.169370e+05  7.923349e+05
# 209             18  9.298056e+06      13.859117  3.707102e+05  7.685538e+05
# 210             19  1.129317e+07      11.764285  6.821544e+05  1.382625e+06
# 211              1  3.713112e+07       1.710916  2.173803e+06  4.850309e+06
# 212              2  2.246648e+07       9.815551  8.113699e+05  1.925237e+06
# 213              3  2.548777e+07      23.727266  8.641269e+05  2.287416e+06
# 214              4  1.378626e+07     540.767005  9.387956e+05  1.633694e+06
# 215              5  1.152497e+07       5.192246  8.590980e+05  1.631447e+06
# 216              6  2.220075e+07     885.641402  9.942686e+05  1.963713e+06
# 217              7  1.642190e+07      12.500808  1.043427e+06  2.123147e+06
# 218              8  1.732552e+07    2783.077620  8.014541e+05  2.045187e+06
# 219              9  2.108436e+07      39.409049  6.939439e+05  1.588685e+06
# 220             10  1.893135e+07      28.758077  5.813484e+05  1.403624e+06
# 221             11  1.076835e+07     361.366863  7.750150e+05  1.416708e+06
# 222             12  3.000201e+06    2938.258115  5.607177e+05  7.775707e+05
# 223             13  1.097755e+07    4198.966358  2.928392e+05  6.188611e+05
# 224             14  1.104732e+07      14.089340  5.954264e+05  1.054160e+06
# 225             15  8.750612e+06      17.208143  1.001985e+06  1.464442e+06
# 226             16  9.334973e+06      22.344027  9.501540e+05  1.611830e+06
# 227             17  9.324645e+05     104.720407  1.330984e+04  1.152538e+05
# 228             18  7.991820e+06  909769.501934  3.626319e+06  3.943885e+06
#
# [229 rows x 7 columns]

# %%
import matplotlib.pyplot as plt

courses_list = df_main.groupby(["course_id", "course_title"])['module_number'].nunique().reset_index()

for index, row in courses_list.iterrows():
    fig, subplot = plt.subplots()
    fig.set_size_inches(10.5,6.5 , forward=True)
    subplot.grid()
    course_data = df_result[(df_result['course_id'] == row.course_id)]
    subplot.set_title(row.course_title)
    subplot.plot(course_data['module_number'], course_data['mean'])  
    subplot.xaxis.set_ticks((course_data['module_number'].values))
    
    subplot.set_ylabel('Медианное время завершения домашней работы')
    subplot.set_xlabel('Номер модуля')
    plt.xticks(rotation='vertical')

plt.show()

# %%
import pandas as pd

df_main_2 = df_main.copy()

df_main_2 = df_main_2.dropna()
df_main_2['finish_month'] = df_main_2['finish_date'].apply(lambda x: x[0:7]) 

df_main_2['start_date'] = pd.to_datetime(df_main_2['start_date'])
df_main_2['finish_date'] = pd.to_datetime(df_main_2['finish_date'])

df_main_2 = df_main_2[(df_main_2['finish_date'] > df_main_2['start_date'])]

df_result = df_main_2.groupby(['course_id', 'course_title', 'finish_month','progress_id']).agg({'start_date': 'min', 'finish_date':'max'}).reset_index()
df_result['difference'] = (df_result['finish_date'] - df_result['start_date']).dt.total_seconds()
df_result = df_result.groupby(['course_id', 'course_title', 'finish_month'])['difference'].agg({'median'}).reset_index()

df_result['finish_month'] = pd.to_datetime(df_result['finish_month'])

df_result
# Out:
#                             course_id                   course_title  \
# 0    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 1    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 2    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 3    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 4    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 5    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 6    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 7    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 8    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 9    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 10   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 11   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 12   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 13   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 14   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 15   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 16   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 17   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 18   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 19   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 20   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 21   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 22   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 23   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 24   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 25   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 26   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 27   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 28   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 29   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# ..                                ...                            ...
# 254  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 255  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 256  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 257  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 258  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 259  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 260  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 261  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 262  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 263  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 264  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 265  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 266  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 267  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 268  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 269  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 270  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 271  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 272  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 273  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 274  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 275  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 276  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 277  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 278  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 279  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 280  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 281  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 282  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 283  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
#
#     finish_month        median
# 0     2017-07-01  3.625000e+03
# 1     2017-10-01  3.747016e+06
# 2     2018-01-01  2.464470e+05
# 3     2018-02-01  2.462950e+05
# 4     2018-03-01  9.452814e+05
# 5     2018-04-01  1.837939e+06
# 6     2018-05-01  1.360961e+06
# 7     2018-06-01  6.530342e+05
# 8     2018-07-01  1.885033e+06
# 9     2018-08-01  1.880490e+06
# 10    2018-09-01  1.963012e+06
# 11    2018-10-01  3.170770e+06
# 12    2018-11-01  2.949840e+06
# 13    2018-12-01  2.362356e+06
# 14    2019-01-01  3.382835e+06
# 15    2019-02-01  2.625994e+06
# 16    2019-03-01  3.917517e+06
# 17    2019-04-01  3.330344e+06
# 18    2019-05-01  2.907745e+06
# 19    2019-06-01  3.127369e+06
# 20    2019-07-01  1.639093e+06
# 21    2017-05-01  1.156660e+05
# 22    2017-06-01  1.140785e+06
# 23    2017-07-01  6.927690e+05
# 24    2017-08-01  2.083160e+05
# 25    2017-09-01  8.972570e+05
# 26    2017-10-01  2.420473e+06
# 27    2017-11-01  2.159341e+06
# 28    2017-12-01  5.361535e+05
# 29    2018-01-01  2.519690e+05
# ..           ...           ...
# 254   2018-07-01  1.122918e+06
# 255   2018-08-01  1.386928e+06
# 256   2018-09-01  2.182497e+06
# 257   2018-10-01  2.404325e+06
# 258   2018-11-01  2.426169e+06
# 259   2018-12-01  2.020728e+06
# 260   2019-01-01  2.713645e+06
# 261   2019-02-01  2.553301e+06
# 262   2019-03-01  2.411526e+06
# 263   2019-04-01  2.207490e+06
# 264   2019-05-01  2.071061e+06
# 265   2019-06-01  2.202345e+06
# 266   2019-07-01  8.369747e+05
# 267   2018-03-01  1.033077e+06
# 268   2018-04-01  1.990971e+06
# 269   2018-05-01  1.353653e+06
# 270   2018-06-01  1.555500e+06
# 271   2018-07-01  2.012688e+06
# 272   2018-08-01  1.873334e+06
# 273   2018-09-01  1.697068e+06
# 274   2018-10-01  2.163744e+06
# 275   2018-11-01  1.899933e+06
# 276   2018-12-01  2.198757e+06
# 277   2019-01-01  2.911564e+06
# 278   2019-02-01  3.013959e+06
# 279   2019-03-01  3.009596e+06
# 280   2019-04-01  2.244444e+06
# 281   2019-05-01  2.013922e+06
# 282   2019-06-01  2.464237e+06
# 283   2019-07-01  9.930635e+05
#
# [284 rows x 4 columns]

# %%
import matplotlib.pyplot as plt

courses_list = df_main.groupby(["course_id", "course_title"])['module_number'].nunique().reset_index()

fig, subplot = plt.subplots()
fig.set_size_inches(18.5, 10.5, forward=True)
subplot.grid()
for index, row in courses_list.iterrows():
    course_data = df_result[(df_result['course_id'] == row.course_id)] 
    
    subplot.plot(course_data['finish_month'], course_data['median'])
    
subplot.xaxis.set_ticks(df_result.groupby('finish_month').sum().reset_index()['finish_month'].values)
plt.legend(courses_list['course_title'])
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## Выводы по второму блоку
# 1.  В каждом курсе есть модули среднее время выполнения домашних заданий по которым сильно больеш остальных. В большинстве курсов -это первый или последнйи модуль. Сложно сказать, проблеммные они или нет. Скорее всего это связано с тем, что последняя тема обычно сама сложная, а первую домашку делть сложно т.к. студент ещё мало знает.
#
# 2. По сезонности можно сказать, что явно прослеживается увеличение числа сдач домашних работ в начале года, максимальное число сдач февраль-март

# %% [markdown]
# ## 4. Расчет конверсии
#
# 1. **(p)** Посчитать конверсию перехода студентов из одного модуля в другой на каждом курсе. Формула: отношение количества студентов, приступивших к выполнению домашнего задания в этом модуле (если дз в модуле несколько, то считать по первому дз в модуле), к количеству студентов, сдавших задание в предыдущем модуле (если дз в модуле несколько, то считать по последнему дз в модуле).
# 2. **(m)** Постройте bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. График должен иметь заголовок. Ticks нужно развернуть так, чтобы они были читаемы
# 3. **(m)** Постройте горизонтальный (столбцы должны располагаться горизонтально) bar-chart, отражающий конверсию перехода студентов из одного модуля в другой на каждом курсе. 15 графиков. Графики должны иметь заголовки. Ticks должны содержать номер и название модуля. Цвет столбцов графиков должен содержать информацию о сфере, к которой относится курс (нужна легенда). Прозрачность должна стоять на отметке 0.1. На графики должна быть нанесена линия медианы конверсии для каждого курса. У медианы должен быть свой цвет. Рамок у графиков быть не должно ⭐
# 4. На основании рассчитанных значений сделайте аналитический вывод (должен быть полным и покрывать все полученные выше метрики)

# %%
import pandas as pd

df_main_3 = df_main.copy()
 
df_main_3['start_count'] = 1 

df_main_3['finish_count'] = df_main_3['status']=='done'
df_main_3['finish_count'] = df_main_3['finish_count'].astype(int)
#df_main_3 = df_main_3[(df_main_3['status']=='done')]

df_result =  df_main_3.groupby(['course_id', 'course_title', 'module_number']).agg({'finish_count':'sum', 'start_count':'sum'}).reset_index()

df_result['finish_count_prev'] = 0

for i in range(1, df_result.shape[0]):
    df_result.iloc[i,5] = df_result.iloc[i-1,3]
    
df_result['conv'] = df_result['start_count']/df_result['finish_count_prev'] 

df_result = df_result[(df_result['module_number']!=1)]

df_result
# Out:
#                             course_id                   course_title  \
# 1    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 2    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 3    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 4    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 5    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 6    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 7    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 8    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 9    04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 10   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 11   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 12   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 13   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 14   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 15   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 16   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 17   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 18   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 19   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 20   04ba6d0b40670c43a209141fa01fa784           Анимация интерфейсов
# 22   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 23   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 24   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 25   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 26   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 27   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 28   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 29   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 30   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# 31   0770b1b039964228294f1f34b29fc2c1  Руководитель digital-проектов
# ..                                ...                            ...
# 198  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 199  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 200  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 201  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 202  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 203  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 204  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 205  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 206  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 207  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 208  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 209  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 210  e3a0df907589d56692b5cb561fd90d87          Веб-дизайн с нуля 2.0
# 212  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 213  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 214  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 215  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 216  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 217  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 218  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 219  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 220  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 221  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 222  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 223  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 224  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 225  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 226  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 227  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
# 228  e9bb9205eeed307ee7cbaa08bfd166c3              JavaScript с нуля
#
#      module_number  finish_count  start_count  finish_count_prev      conv
# 1                2           770          832               1040  0.800000
# 2                3           810          887                770  1.151948
# 3                4           589          627                810  0.774074
# 4                5           444          465                589  0.789474
# 5                6            84           89                444  0.200450
# 6                7           260          282                 84  3.357143
# 7                8           191          217                260  0.834615
# 8                9            52           52                191  0.272251
# 9               10           301          308                 52  5.923077
# 10              11           120          126                301  0.418605
# 11              12           116          119                120  0.991667
# 12              13           158          168                116  1.448276
# 13              14           105          113                158  0.715190
# 14              15            94          100                105  0.952381
# 15              16            20           20                 94  0.212766
# 16              17            76           78                 20  3.900000
# 17              18            72           79                 76  1.039474
# 18              19            20           20                 72  0.277778
# 19              20            19           19                 20  0.950000
# 20              21             5           16                 19  0.842105
# 22               2          1470         1661               2398  0.692661
# 23               3          1596         1697               1470  1.154422
# 24               4           918         1046               1596  0.655388
# 25               5           946          982                918  1.069717
# 26               6          1065         1081                946  1.142706
# 27               7          1163         1215               1065  1.140845
# 28               8          1910         1937               1163  1.665520
# 29               9           540          550               1910  0.287958
# 30              10           613          636                540  1.177778
# 31              11           642          652                613  1.063622
# ..             ...           ...          ...                ...       ...
# 198              7          4987         5055               1011  5.000000
# 199              8           944          955               4987  0.191498
# 200              9          2712         2845                944  3.013771
# 201             10          4028         4110               2712  1.515487
# 202             11          2866         2951               4028  0.732622
# 203             12          3190         3236               2866  1.129100
# 204             13          3605         3650               3190  1.144201
# 205             14          2727         2774               3605  0.769487
# 206             15          2000         2056               2727  0.753942
# 207             16          1816         1854               2000  0.927000
# 208             17          2105         2125               1816  1.170154
# 209             18          1588         1624               2105  0.771496
# 210             19          1412         1548               1588  0.974811
# 212              2          4654         4799               3803  1.261899
# 213              3          2069         2125               4654  0.456596
# 214              4          1950         1991               2069  0.962301
# 215              5           901          943               1950  0.483590
# 216              6           565          597                901  0.662597
# 217              7           587          604                565  1.069027
# 218              8           713          725                587  1.235094
# 219              9           745          755                713  1.058906
# 220             10           747          756                745  1.014765
# 221             11           460          468                747  0.626506
# 222             12           476          485                460  1.054348
# 223             13           562          567                476  1.191176
# 224             14           341          349                562  0.620996
# 225             15           296          309                341  0.906158
# 226             16           266          284                296  0.959459
# 227             17            84           84                266  0.315789
# 228             18            13           27                 84  0.321429
#
# [214 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np
courses_list = df_main.groupby(["course_id", "course_title"])['module_number'].nunique().reset_index()

x = np.arange(-1/16*11,1/16*11,1/16)  # the label locations

width = 1/15  # the width of the bars

fig, subplot = plt.subplots()
fig.set_size_inches(18.5, 10.5, forward=True)

for index, row in courses_list.iterrows():
    course_data = df_result[(df_result['course_id'] == row.course_id)]
    subplot.bar(
        course_data['module_number'].values+x[index], 
              course_data['conv'].values, width,)

subplot.xaxis.set_ticks(range(0, 22, 1))
plt.legend(courses_list['course_title'])
plt.show()

# %% [markdown]
# ## Выводы по второму блоку
# 1.  По курсам web-дизайн и web-дизайн базовый очень много модулей с конверсией больше 100%. Значит студенты часто переходят на
# следующий модуль не сдав ДЗ по предыдушему. Надо обрать внимание на модули 3,5,8,11,15 курса web-дизайн Pro. На курсе web-дизайн базовый почти все модули с конверсией больше 100%.
# 2. Есть модули с очень маленкой конверсией т.е. люди не приступают к домашке, хотя сдали пердыдущий модуль. 8й модуль PHP, 10й по Веб дизайн базовый, 17й по Интернет маркетингу.

# %% [markdown]
# ## 5. Метрика успеваемости
#
# &nbsp;&nbsp;&nbsp;&nbsp;*(необязательное задание)*
#
# Иногда студенты берут курсы, которые оказываются для них неподъемными. Это может быть как по причинам недостаточной изначальной подготовки, так и по причинам, связанным с низкой мотивацией студента. Для улучшения качества контента полезно выявить причину. На основании имеющихся данных придумайте метрику успеваемости студента. **Обоснуйте ее.** Выявите таких студентов на каждом курсе, чтобы предоставить продюсерам список проблемных студентов.

# %%
df_main_4 = df_main.copy()
 
df_main_4['done'] = df_main_4['status']=='done'
df_main_4['done'] = df_main_4['done'].astype(int)

df_main_4 = df_main_4.groupby('student_id').agg({'status':'count', 'done':'sum'}).reset_index()

df_main_4['perf'] = df_main_4['done']/df_main_4['status']

df_main_4.sort_values(by=['perf','status'],  ascending=[True, False])
# Out:
#                             student_id  status  done  perf
# 6004  a002a005048ae8cc2ff6cdc120cf3aad      10     0   0.0
# 1233  20804c32da13576833a5124961cd08f1       9     0   0.0
# 4045  6cdeb0b754b18270d7654a02d4a9a5d8       6     0   0.0
# 9558  fa00ce7a14ab3a06a6397f6359b32e27       6     0   0.0
# 1961  349e069edb6e004408f968eb009036d0       5     0   0.0
# 9305  f3c647effcc61fe92413a2be3b4464cd       5     0   0.0
# 76    02107aa47b83ec1483a5376fcc600664       4     0   0.0
# 854   16b234aedd336507ae03c70d405cbd7b       4     0   0.0
# 3832  667471516e7f194b35fb47c885371459       4     0   0.0
# 4491  797e4e8a7019305ac470904b81875e97       4     0   0.0
# 4885  82ff711adeab1378b0e1dc6fd7f568b1       4     0   0.0
# 6551  ad44a61fc4f81e3212bf76a4f96a1e62       4     0   0.0
# 6826  b401cd76ccb61fb6fb87773a05cc600a       4     0   0.0
# 8999  ebdaaac3202de780a94bcb54900ebd83       4     0   0.0
# 363   0926b617c590d4525d9ec1b260dfa228       3     0   0.0
# 502   0cef0340ae70b958276b33d28d2c6423       3     0   0.0
# 1064  1c39a719f3d4b91bbc69167092df0431       3     0   0.0
# 1112  1d637543d9508a0d66a2b5e0d00bce33       3     0   0.0
# 1360  23d31643d11c03b710996ff62b75d935       3     0   0.0
# 1503  27defbc55b185ce1359d056b229545b6       3     0   0.0
# 1579  29d37c49e641c33d5bcfa12620ef4018       3     0   0.0
# 2093  3840c62c9f093af8db9b1ec958b3b7b8       3     0   0.0
# 2396  3f468a5c088c3590070bcf441c893ef2       3     0   0.0
# 2811  4aa660cb2fa5b05e44380e6bcfb8d67a       3     0   0.0
# 2836  4b4d3cbfba5d869a6f13e4d9a46ea703       3     0   0.0
# 3166  545c7ecbf2469553b254483e9a3a48e6       3     0   0.0
# 3181  54cd94d81461899a14b8e0eed232fd25       3     0   0.0
# 3270  576a38fbd4e77d267dac75d71ac1fc5b       3     0   0.0
# 3485  5c9262ae18f83e466c035aba888ad368       3     0   0.0
# 3903  686c3a8421f02d1ee1159e073dfd7ac5       3     0   0.0
# ...                                ...     ...   ...   ...
# 6418  aa37724cc19b05b0d6bab4c076538216       1     1   1.0
# 6907  b6567479cb37bd754deded3fa73fdacf       1     1   1.0
# 6949  b7887f6d0b0981097416069a81f3e48f       1     1   1.0
# 7015  b90e440def5b7a643395eed52c02a339       1     1   1.0
# 7045  b9acbe111d4d75f88c8104fca82acbdd       1     1   1.0
# 7050  b9df957534c53b582046390b1128ff36       1     1   1.0
# 7163  bcffe6dc020103b3de312f5c775fa668       1     1   1.0
# 7179  bd8410552644c2878b2143b6983d240f       1     1   1.0
# 7188  bdc73925dbd3696c1a84a0ee3a6faeb0       1     1   1.0
# 7234  bee48a0bd5469c14ddf16dd2834cad3e       1     1   1.0
# 7391  c34a0171553b46656b9b81cd581e388b       1     1   1.0
# 7457  c4d5cb708264f9edb082ef261400a136       1     1   1.0
# 7499  c5e8b2f19100a3bb68c12d50c7e180cf       1     1   1.0
# 7501  c5fbd64664ff7a3fe7324f3892e4c9a0       1     1   1.0
# 7673  ca5fe25e2f961c8a96ff5becc19f6a4e       1     1   1.0
# 7885  cfbd10aa4dcfe3a53dedd27dd0df3bd9       1     1   1.0
# 7947  d13f24ae3dd8b6588e063a67d5c5d59e       1     1   1.0
# 8120  d594dd246953a1f5526d99e42efe7124       1     1   1.0
# 8163  d6bbbd7c24f1e614939b1c57202bff78       1     1   1.0
# 8179  d7389db29d42ecd34b09206ba846316b       1     1   1.0
# 8181  d740991a65202b2153eebf323e07b6c3       1     1   1.0
# 8319  db014abd3c83f3fd4febdf77db28d077       1     1   1.0
# 8461  deb1724d22e87cd01f8e429bc04db4ef       1     1   1.0
# 9099  eea241a15e55c3ca953586bfb6b67eaa       1     1   1.0
# 9175  f0b6ea07016e88e8b739b7ec51f889e7       1     1   1.0
# 9224  f1ec0332c0190893a180bc4b1cb90bce       1     1   1.0
# 9300  f3a696a85b074788cee342ec48348cab       1     1   1.0
# 9478  f85035fb9fea3d33ea8a4846ee9e9cc0       1     1   1.0
# 9656  fc72c02ad6d67190ff2d7f40a26f3463       1     1   1.0
# 9678  fcdf7fff8ae02686a0a900035f343b99       1     1   1.0
#
# [9794 rows x 4 columns]

# %% [markdown]
# В качетсве метрики успеваеости я использовал отношение количества начатых домашних заданий к количеству завершенных. Список я уворядочил по местрике, а затем по количеству начатых заданий. Метрика разработана из той логики, что чем больше студен начал заданий и меньше при этом закончил тем меньше у него успеваемост.
