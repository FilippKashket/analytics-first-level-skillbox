# %% [markdown]
# # Курсовая работа № 2
# ## Аналитика. Начальный уровень
#
# Курсовая работа состоит из двух частей – обязательной и дополнительной. **Для зачета необходимо выполнение только первой части.** Выполнение второй части может потребовать дополнительные знания Python.
#
# - [Часть первая](#Часть-первая)
# - [Часть вторая](#Часть-вторая)

# %% [markdown]
# ## Часть первая
#
#
# Перед вами стоит задача – подготовить аналитический отчет для HR-отдела. На основании проведенной аналитики предполагается составить рекомендации для отдела кадров по стратегии набора персонала, а также по взаимодействию с уже имеющимися сотрудниками.
# <br><br> В базе данных лежит набор таблиц, которые содержат данные о сотрудниках вымышленной компании.
# Сделайте обзор штата сотрудников компании. Составьте набор предметов исследования, а затем проверьте их на данных. Вся аналитика должна быть выполена с помощью SQL. Впоследствии данные можно визуализировать, однако финальные датафреймы для графиков также должны быть подготовлены с помощью SQL. <br><br>
#
# Примеры гипотез:
# 1. Есть зависимость между `perfomance score` и тем, под чьим руководством работает сотрудник.
# 2. Есть зависимость между продолжительностью работы в компании и семейным положением сотрудника.
# 2. Есть зависимость между продолжительностью работы в компании и возрастом сотрудника.
#
# <br><br>
# Параметры для подключения следующие: хост – `dsstudents.skillbox.ru`, порт – `5432`, имя базы данных – `human_resources`, пользователь – `readonly`, пароль – `6hajV34RTQfmxhS`. Таблицы, доступные для анализа, – `hr_dataset`, `production_staff`, `recruting_costs`, `salary_grid`.

# %% [markdown]
# ## Предположения:
#     1. Сотрудники с большей средней зарплатой дольше работают в компании
#     2. Есть зависимость между рассой и оценкой производиетльности.
#     3. Есть зависимость между зарплатой и проиводительностью.
#     4. Есть зависимость между зарплатой сотрудника в час и средней стоимостью рекрутинга

# %%
# Сотрудники с большей средней зарплатой дольше работают в компании
import psycopg2
import pandas as pd
import matplotlib.pyplot as plt

pg_connection = {
    "host": "dsstudents.skillbox.ru",
    "port":5432,
    "dbname":"human_resources",
    "user":"readonly",
    "password":"6hajV34RTQfmxhS"
}

conn = psycopg2.connect(**pg_connection);

cursor = conn.cursor()

df = pd.read_sql_query("""SELECT AVG(hr_dataset."Days Employed") AS days_employed,
                            salary_grid."Salary Mid" AS salary_mid
                            FROM hr_dataset LEFT JOIN salary_grid ON hr_dataset.position=salary_grid."Position" 
                            WHERE hr_dataset."Date of Termination" is not null GROUP BY salary_mid""", conn)



conn.commit();


df.dropna()
df= df.sort_values(by='days_employed');

fig, subplot = plt.subplots()
fig.set_size_inches(10.5,6.5 , forward=True)
subplot.grid()
subplot.plot(df['days_employed'], df['salary_mid'])

# %% [markdown]
# 1. В некотормо смысле получилась обратная картина. Люди на должностях с высокой средней оплатой работают в среднем меньше (до момента увольнения) чем люди с более высокой оплатой. Возможно более дорогие и востребованные специалисты не находят в данной компании места для карьерного роста и развития. Стоит разработать тест и провести анкетирование среди таких специалистов, чтобы попытаться выяснить причины.

# %%
#Есть зависимость между рассой и оценкой производиетльности.
df = pd.read_sql_query("""SELECT production_staff."Race Desc" as race, 
                            SUM(CASE 
                                WHEN production_staff."Performance Score" = 'Fully Meets' 
                                    THEN 1 
                                    ELSE 0 
                            END) as fully_meets,
                            SUM(CASE 
                                WHEN production_staff."Performance Score" = 'Exceptional' 
                                    THEN 1
                                    ELSE 0 
                            END) as exceptional,
                            SUM(CASE
                                WHEN production_staff."Performance Score" = '90-day meets'
                                    THEN 1
                                    ELSE 0
                            END) as ninety_day_meets,
                            SUM(CASE
                                WHEN production_staff."Performance Score" = 'N/A- too early to review'
                                    THEN 1
                                    ELSE 0
                            END) as too_early,
                            SUM(CASE
                                WHEN production_staff."Performance Score" = 'Needs Improvement'
                                    THEN 1
                                    ELSE 0
                            END) as needs_improvement,
                            SUM(CASE
                                WHEN production_staff."Performance Score" = 'Exceeds'
                                    THEN 1
                                    ELSE 0
                            END) as exceeds,
                            SUM(CASE
                                WHEN production_staff."Performance Score" = 'PIP'
                                    THEN 1
                                    ELSE 0
                            END) as pip,
                            COUNT(production_staff."Race Desc")
                       FROM production_staff GROUP BY  race""", conn)

conn.commit()

df = df.dropna()

df
# Out:
#                                race  fully_meets  exceptional  \
# 1                          Hispanic            2            0
# 2                             Asian           14            0
# 3                             White           80            3
# 4         Black or African American           20            1
# 5  American Indian or Alaska Native            1            0
# 6                 Two or more races            5            0
#
#    ninety_day_meets  too_early  needs_improvement  exceeds  pip  count
# 1                 0          1                  0        0    0      3
# 2                 2          2                  1        2    1     22
# 3                14         19                  5       15    4    140
# 4                 1          2                  5        1    1     31
# 5                 0          0                  0        2    0      3
# 6                 1          1                  0        2    1     10

# %% [markdown]
# 2. Никакой явной зависимости между рассой и оценкой производиельности не наблюдается.

# %%
#Есть зависимость между зарплатой и проиводительностью.
import matplotlib.pyplot as plt

df = pd.read_sql_query(""" SELECT AVG(RIGHT(production_staff."Pay"::varchar,5)::float) as pay,
                            production_staff."Performance Score" as performance_score 
                            FROM production_staff GROUP BY performance_score """, conn)

conn.commit()
df = df.dropna()

df = df.sort_values(by='pay', ascending=False)

fig, subplot = plt.subplots()
fig.set_size_inches(18.5, 10.5, forward=True)

subplot.bar(df['performance_score'],
          df['pay']) 

plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 3. Средняя зарплата чуть выше у сотрудников квалфикация которых требует улучшения, на тертьем месте. Стоит обратить внимание на систему оплаты труда. Возможно компания переплачивает тем кому можно платитьм еньше и недоплачивает тем кому следует.

# %%
#Есть зависимость между зарплатой сотрудника в час и средней стоимостью рекрутинга
import matplotlib.pyplot as plt

df = pd.read_sql_query("""SELECT hr_dataset."Employee Name", hr_dataset."Employee Source", RIGHT(production_staff."Pay"::varchar,5)::float as pay,
                            production_staff."Performance Score" as performance_score, recruiting_costs."Total"/12::float as cost 
                            FROM hr_dataset LEFT JOIN production_staff 
                                ON hr_dataset."Employee Name"=production_staff."Employee Name" 
                            LEFT JOIN recruiting_costs 
                                ON hr_dataset."Employee Source" = recruiting_costs."Employment Source"  """, conn)
df = df.dropna()
df = df.sort_values(by='cost', ascending=True)

#f= df.sort_values(by='days_employed');

fig, subplot = plt.subplots()
fig.set_size_inches(10.5,6.5 , forward=True)
subplot.grid()
subplot.plot(df['cost'], df['pay'])
#df

# %% [markdown]
# 4. Зависимости между зарплатой сотрудника в час и средней стоимостью рекрутинга нет. Есть даже сотрудники стоимость рекрутинга которых очень высока, а зарптала низкая. Стоит посмотреть их должности.

# %%
import matplotlib.pyplot as plt

df = pd.read_sql_query("""SELECT position,AVG(pay),AVG(cost) FROM (SELECT hr_dataset.position , hr_dataset."Employee Name", hr_dataset."Employee Source", RIGHT(production_staff."Pay"::varchar,5)::float as pay,
                            production_staff."Performance Score" as performance_score, recruiting_costs."Total"/12::float as cost 
                            FROM hr_dataset LEFT JOIN production_staff 
                                ON hr_dataset."Employee Name"=production_staff."Employee Name" 
                            LEFT JOIN recruiting_costs 
                                ON hr_dataset."Employee Source" = recruiting_costs."Employment Source") as data WHERE pay<30 AND cost>600 GROUP BY position  """, conn)
df = df.dropna()
#df = df.sort_values(by='cost', ascending=True)
df
# Out:
#                    position        avg         avg
# 0   Production Technician I  19.045455  784.418561
# 1  Production Technician II  25.343750  740.104167

# %% [markdown]
# Две должности с самой высокой стоимостью рекрутинга и самой низкой зарплатой. Production Technician I и Production Technician II.

# %% [markdown]
# ## Часть вторая

# %% [markdown]
# Перед вами стоит задача – подготовить аналитический ответ для SMM-отдела компании Skillbox. <br> Объектом анализа является  [паблик Skillbox Вконтакте](https://vk.com/skillbox_education). <br> <br>
# Подключитесь к  API VK и выгрузите посты со стены паблика Skillbox за интересующий период (определите самостоятельно и обоснуйте). Проанализируйте влияние различных факторов (например, времени публикации) на вовлеченность пользователей (количество лайков, комментариев, голосов в опросах). Сделайте аналитику по рубрикам (примеры рубрик: дизайн-битва, игра по управлению), которые есть в паблике. Выбрать нужные посты можно с помощью регулярных выражений. Составьте перечень рекомандаций для SMM-отдела по итогам анализа. <br> <br>
#
# Дополнительные инструкции по работе с API VK расположены [здесь](https://nbviewer.jupyter.org/github/vikaborel/dstutorials/blob/master/Дополнительные%20инструкции.ipynb).

# %%
#Я использовал данные за год, т.к. могут быть какие-то зависимости от времени года
import requests
from datetime import datetime, timedelta
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re

def getjson(url):
    response = requests.get(url)
    response = response.json()
    return response

vk_token = "7e885d7fedad8baa1c7eb8af7943b9f11d7c7146f0837737f3ad140b96de1bf8285392cf2f9c7cf47a288"

url = 'https://api.vk.com/method/wall.get?access_token=' + str(vk_token) + '&owner_id=-66669811&count=100&v=5.92'
response = getjson(url)

list_result = response['response']['items'] 

date = list_result[0]['date']
dt = datetime.fromtimestamp(date) - timedelta(hours=0)

start_date = dt 

date = list_result[99]['date']
dt = datetime.fromtimestamp(date) - timedelta(hours=0)

finish_date = dt 

offset=100
while((start_date-finish_date)<=timedelta(days=365)):
    url = 'https://api.vk.com/method/wall.get?access_token=' + str(vk_token) + '&owner_id=-66669811&offset='+str(offset)+'&count=100&v=5.92'
    response = getjson(url)
    list_result+= response['response']['items']
    date = list_result[offset+99]['date']
    dt = datetime.fromtimestamp(date) - timedelta(hours=0)
    finish_date = dt
    offset+=100;

df = pd.DataFrame(list_result)

reg_expr = r'#\w+'
reg_expr_compiled = re.compile(reg_expr)

df['tags'] = df['text'].apply(lambda x: reg_expr_compiled.findall(x))
df['comments_count'] = df['comments'].apply(lambda x:  x['count'])
df['likes_count'] = df['likes'].apply(lambda x:  x['count'])
df['reposts_count'] = df['reposts'].apply(lambda x:  x['count'])
df['views_count'] = df['views'].apply(lambda x:  x['count'])
df['date']=df['date'].apply(lambda x: (datetime.fromtimestamp(x) - timedelta(hours=0)))
df['week_day'] = df['date'].apply(lambda x: datetime.weekday(x))
df['week_day'] = df['week_day'].astype(int)
df['month']= df['date'].apply(lambda x: x.strftime('%Y-%m-%d %H:%M:%S')[5:-12])
df['month'] = df['month'].astype(int)
df['date_full']= df['date'].apply(lambda x: x.strftime('%Y-%m-%d %H:%M:%S'))
df['time']= df['date'].apply(lambda x: x.strftime('%Y-%m-%d %H:%M:%S')[11:-6])
df['time']=df['time'].astype(int)

df
# Out:
#                                            attachments  \
# 0    [{'type': 'photo', 'photo': {'id': 457494821, ...
# 1    [{'type': 'link', 'link': {'url': 'https://ski...
# 2    [{'type': 'link', 'link': {'url': 'https://vk....
# 3    [{'type': 'video', 'video': {'id': 456239767, ...
# 4    [{'type': 'link', 'link': {'url': 'https://ski...
# 5    [{'type': 'photo', 'photo': {'id': 457494794, ...
# 6    [{'type': 'link', 'link': {'url': 'https://ski...
# 7    [{'type': 'doc', 'doc': {'id': 600801855, 'own...
# 8    [{'type': 'video', 'video': {'id': 456239765, ...
# 9    [{'type': 'link', 'link': {'url': 'https://ski...
# 10   [{'type': 'photo', 'photo': {'id': 457494770, ...
# 11   [{'type': 'photo', 'photo': {'id': 457494769, ...
# 12   [{'type': 'photo', 'photo': {'id': 457494761, ...
# 13   [{'type': 'photo', 'photo': {'id': 457494716, ...
# 14   [{'type': 'photo', 'photo': {'id': 457494693, ...
# 15   [{'type': 'photo', 'photo': {'id': 457494684, ...
# 16   [{'type': 'link', 'link': {'url': 'https://ski...
# 17   [{'type': 'video', 'video': {'id': 456239758, ...
# 18   [{'type': 'link', 'link': {'url': 'https://ski...
# 19   [{'type': 'photo', 'photo': {'id': 457494629, ...
# 20   [{'type': 'link', 'link': {'url': 'https://ski...
# 21   [{'type': 'photo', 'photo': {'id': 457494624, ...
# 22   [{'type': 'link', 'link': {'url': 'https://ski...
# 23   [{'type': 'photo', 'photo': {'id': 457494606, ...
# 24   [{'type': 'photo', 'photo': {'id': 457494589, ...
# 25   [{'type': 'photo', 'photo': {'id': 457494572, ...
# 26   [{'type': 'link', 'link': {'url': 'https://ski...
# 27   [{'type': 'link', 'link': {'url': 'https://202...
# 28   [{'type': 'photo', 'photo': {'id': 457494564, ...
# 29   [{'type': 'photo', 'photo': {'id': 457494559, ...
# ..                                                 ...
# 970  [{'type': 'link', 'link': {'url': 'https://www...
# 971  [{'type': 'video', 'video': {'id': 456239480, ...
# 972  [{'type': 'doc', 'doc': {'id': 489502784, 'own...
# 973  [{'type': 'link', 'link': {'url': 'https://ski...
# 974  [{'type': 'link', 'link': {'url': 'https://hab...
# 975  [{'type': 'video', 'video': {'id': 456239480, ...
# 976  [{'type': 'link', 'link': {'url': 'https://ski...
# 977  [{'type': 'photo', 'photo': {'id': 456464961, ...
# 978  [{'type': 'photo', 'photo': {'id': 456464959, ...
# 979  [{'type': 'photo', 'photo': {'id': 456464937, ...
# 980  [{'type': 'photo', 'photo': {'id': 456464936, ...
# 981  [{'type': 'link', 'link': {'url': 'https://ski...
# 982  [{'type': 'video', 'video': {'id': 456239479, ...
# 983  [{'type': 'link', 'link': {'url': 'https://ski...
# 984  [{'type': 'link', 'link': {'url': 'https://hab...
# 985  [{'type': 'photo', 'photo': {'id': 456464924, ...
# 986  [{'type': 'link', 'link': {'url': 'https://ski...
# 987  [{'type': 'link', 'link': {'url': 'https://m.v...
# 988  [{'type': 'link', 'link': {'url': 'https://ski...
# 989  [{'type': 'video', 'video': {'id': 456239478, ...
# 990  [{'type': 'photo', 'photo': {'id': 456464913, ...
# 991  [{'type': 'photo', 'photo': {'id': 456464910, ...
# 992  [{'type': 'video', 'video': {'id': 456239477, ...
# 993  [{'type': 'link', 'link': {'url': 'https://www...
# 994  [{'type': 'link', 'link': {'url': 'https://m.v...
# 995  [{'type': 'photo', 'photo': {'id': 456464845, ...
# 996  [{'type': 'photo', 'photo': {'id': 456464909, ...
# 997  [{'type': 'video', 'video': {'id': 456239472, ...
# 998  [{'type': 'link', 'link': {'url': 'https://ski...
# 999  [{'type': 'link', 'link': {'url': 'https://hab...
#
#                                               comments copy_history  \
# 0    {'count': 2, 'can_post': 1, 'groups_can_post':...          NaN
# 1    {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 2    {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 3    {'count': 11, 'can_post': 1, 'groups_can_post'...          NaN
# 4    {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 5    {'count': 9, 'can_post': 1, 'groups_can_post':...          NaN
# 6    {'count': 1, 'can_post': 1, 'groups_can_post':...          NaN
# 7    {'count': 9, 'can_post': 1, 'groups_can_post':...          NaN
# 8    {'count': 18, 'can_post': 1, 'groups_can_post'...          NaN
# 9    {'count': 2, 'can_post': 1, 'groups_can_post':...          NaN
# 10   {'count': 44, 'can_post': 1, 'groups_can_post'...          NaN
# 11   {'count': 15, 'can_post': 1, 'groups_can_post'...          NaN
# 12   {'count': 11, 'can_post': 1, 'groups_can_post'...          NaN
# 13   {'count': 44, 'can_post': 1, 'groups_can_post'...          NaN
# 14   {'count': 13, 'can_post': 1, 'groups_can_post'...          NaN
# 15   {'count': 17, 'can_post': 1, 'groups_can_post'...          NaN
# 16   {'count': 4, 'can_post': 1, 'groups_can_post':...          NaN
# 17   {'count': 37, 'can_post': 1, 'groups_can_post'...          NaN
# 18   {'count': 2, 'can_post': 1, 'groups_can_post':...          NaN
# 19   {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 20   {'count': 3, 'can_post': 1, 'groups_can_post':...          NaN
# 21   {'count': 28, 'can_post': 1, 'groups_can_post'...          NaN
# 22   {'count': 8, 'can_post': 1, 'groups_can_post':...          NaN
# 23   {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 24   {'count': 2, 'can_post': 1, 'groups_can_post':...          NaN
# 25   {'count': 56, 'can_post': 1, 'groups_can_post'...          NaN
# 26   {'count': 5, 'can_post': 1, 'groups_can_post':...          NaN
# 27   {'count': 6, 'can_post': 1, 'groups_can_post':...          NaN
# 28   {'count': 171, 'can_post': 1, 'groups_can_post...          NaN
# 29   {'count': 15, 'can_post': 1, 'groups_can_post'...          NaN
# ..                                                 ...          ...
# 970  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 971  {'count': 3, 'can_post': 1, 'groups_can_post':...          NaN
# 972  {'count': 1, 'can_post': 1, 'groups_can_post':...          NaN
# 973  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 974  {'count': 6, 'can_post': 1, 'groups_can_post':...          NaN
# 975  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 976  {'count': 2, 'can_post': 1, 'groups_can_post':...          NaN
# 977  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 978  {'count': 95, 'can_post': 1, 'groups_can_post'...          NaN
# 979  {'count': 2, 'can_post': 1, 'groups_can_post':...          NaN
# 980  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 981  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 982  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 983  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 984  {'count': 2, 'can_post': 1, 'groups_can_post':...          NaN
# 985  {'count': 6, 'can_post': 1, 'groups_can_post':...          NaN
# 986  {'count': 2, 'can_post': 1, 'groups_can_post':...          NaN
# 987  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 988  {'count': 1, 'can_post': 1, 'groups_can_post':...          NaN
# 989  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 990  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 991  {'count': 6, 'can_post': 1, 'groups_can_post':...          NaN
# 992  {'count': 2, 'can_post': 1, 'groups_can_post':...          NaN
# 993  {'count': 5, 'can_post': 1, 'groups_can_post':...          NaN
# 994  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 995  {'count': 2, 'can_post': 1, 'groups_can_post':...          NaN
# 996  {'count': 3, 'can_post': 1, 'groups_can_post':...          NaN
# 997  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 998  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 999  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
#
#                    date   from_id     id  is_favorite  \
# 0   2020-01-18 12:08:39 -66669811  49428        False
# 1   2020-01-17 19:15:34 -66669811  49407        False
# 2   2020-01-17 15:31:57 -66669811  49403        False
# 3   2020-01-17 11:00:03 -66669811  49389        False
# 4   2020-01-16 18:01:34 -66669811  49380        False
# 5   2020-01-16 12:04:12 -66669811  49368        False
# 6   2020-01-15 20:03:07 -66669811  49353        False
# 7   2020-01-15 16:40:16 -66669811  49331        False
# 8   2020-01-15 12:00:19 -66669811  49249        False
# 9   2020-01-14 18:01:10 -66669811  49142        False
# 10  2020-01-14 12:36:44 -66669811  49000        False
# 11  2020-01-14 10:35:15 -66669811  48948        False
# 12  2020-01-13 17:55:10 -66669811  48890        False
# 13  2020-01-13 11:40:04 -66669811  48749        False
# 14  2020-01-12 12:01:29 -66669811  48593        False
# 15  2020-01-11 12:23:07 -66669811  48536        False
# 16  2020-01-10 19:05:16 -66669811  48498        False
# 17  2020-01-10 12:00:32 -66669811  48382        False
# 18  2020-01-09 19:00:42 -66669811  48361        False
# 19  2020-01-09 12:01:41 -66669811  48300        False
# 20  2020-01-08 20:01:08 -66669811  48284        False
# 21  2020-01-08 12:10:27 -66669811  48257        False
# 22  2020-01-06 19:00:29 -66669811  48213        False
# 23  2020-01-06 13:42:49 -66669811  48209        False
# 24  2020-01-04 11:30:42 -66669811  48181        False
# 25  2020-01-02 12:40:13 -66669811  48116        False
# 26  2019-12-30 19:30:17 -66669811  48050        False
# 27  2019-12-30 15:50:46 -66669811  48026        False
# 28  2019-12-30 11:00:47 -66669811  47949        False
# 29  2019-12-29 12:02:19 -66669811  47932        False
# ..                  ...       ...    ...          ...
# 970 2019-01-18 19:30:01 -66669811  30808        False
# 971 2019-01-18 17:30:02 -66669811  30804        False
# 972 2019-01-18 15:30:02 -66669811  30803        False
# 973 2019-01-18 11:45:22 -66669811  30792        False
# 974 2019-01-17 19:30:02 -66669811  30784        False
# 975 2019-01-17 17:30:01 -66669811  30780        False
# 976 2019-01-17 15:30:02 -66669811  30766        False
# 977 2019-01-17 11:36:31 -66669811  30711        False
# 978 2019-01-17 10:30:05 -66669811  30684        False
# 979 2019-01-16 19:30:01 -66669811  30681        False
# 980 2019-01-16 17:30:01 -66669811  30680        False
# 981 2019-01-16 16:00:11 -66669811  30679        False
# 982 2019-01-16 15:30:01 -66669811  30677        False
# 983 2019-01-16 11:30:32 -66669811  30675        False
# 984 2019-01-15 19:30:01 -66669811  30665        False
# 985 2019-01-15 17:30:01 -66669811  30658        False
# 986 2019-01-15 15:30:02 -66669811  30657        False
# 987 2019-01-15 10:30:01 -66669811  30653        False
# 988 2019-01-14 17:30:01 -66669811  30651        False
# 989 2019-01-14 15:30:01 -66669811  30649        False
# 990 2019-01-14 13:00:07 -66669811  30648        False
# 991 2019-01-13 15:30:00 -66669811  30636        False
# 992 2019-01-12 15:30:00 -66669811  30621        False
# 993 2019-01-12 13:00:05 -66669811  30618        False
# 994 2019-01-12 10:30:01 -66669811  30615        False
# 995 2019-01-11 19:30:02 -66669811  30607        False
# 996 2019-01-11 17:30:03 -66669811  30602        False
# 997 2019-01-11 15:30:03 -66669811  30600        False
# 998 2019-01-11 12:23:00 -66669811  30595        False
# 999 2019-01-10 19:30:03 -66669811  30590        False
#
#                                                  likes  marked_as_ads  \
# 0    {'count': 66, 'user_likes': 0, 'can_like': 1, ...              0
# 1    {'count': 32, 'user_likes': 0, 'can_like': 1, ...              0
# 2    {'count': 20, 'user_likes': 0, 'can_like': 1, ...              0
# 3    {'count': 42, 'user_likes': 0, 'can_like': 1, ...              0
# 4    {'count': 24, 'user_likes': 0, 'can_like': 1, ...              0
# 5    {'count': 40, 'user_likes': 0, 'can_like': 1, ...              0
# 6    {'count': 77, 'user_likes': 0, 'can_like': 1, ...              0
# 7    {'count': 25, 'user_likes': 0, 'can_like': 1, ...              0
# 8    {'count': 157, 'user_likes': 0, 'can_like': 1,...              0
# 9    {'count': 32, 'user_likes': 0, 'can_like': 1, ...              0
# 10   {'count': 18, 'user_likes': 0, 'can_like': 1, ...              0
# 11   {'count': 61, 'user_likes': 0, 'can_like': 1, ...              0
# 12   {'count': 79, 'user_likes': 0, 'can_like': 1, ...              0
# 13   {'count': 22, 'user_likes': 0, 'can_like': 1, ...              0
# 14   {'count': 77, 'user_likes': 0, 'can_like': 1, ...              0
# 15   {'count': 419, 'user_likes': 0, 'can_like': 1,...              0
# 16   {'count': 64, 'user_likes': 0, 'can_like': 1, ...              0
# 17   {'count': 233, 'user_likes': 0, 'can_like': 1,...              0
# 18   {'count': 58, 'user_likes': 0, 'can_like': 1, ...              0
# 19   {'count': 91, 'user_likes': 0, 'can_like': 1, ...              0
# 20   {'count': 40, 'user_likes': 0, 'can_like': 1, ...              0
# 21   {'count': 26, 'user_likes': 0, 'can_like': 1, ...              0
# 22   {'count': 112, 'user_likes': 0, 'can_like': 1,...              0
# 23   {'count': 359, 'user_likes': 0, 'can_like': 1,...              0
# 24   {'count': 98, 'user_likes': 0, 'can_like': 1, ...              0
# 25   {'count': 31, 'user_likes': 0, 'can_like': 1, ...              0
# 26   {'count': 95, 'user_likes': 0, 'can_like': 1, ...              0
# 27   {'count': 63, 'user_likes': 0, 'can_like': 1, ...              0
# 28   {'count': 125, 'user_likes': 0, 'can_like': 1,...              0
# 29   {'count': 58, 'user_likes': 0, 'can_like': 1, ...              0
# ..                                                 ...            ...
# 970  {'count': 36, 'user_likes': 0, 'can_like': 1, ...              0
# 971  {'count': 169, 'user_likes': 0, 'can_like': 1,...              0
# 972  {'count': 26, 'user_likes': 0, 'can_like': 1, ...              0
# 973  {'count': 28, 'user_likes': 0, 'can_like': 1, ...              0
# 974  {'count': 18, 'user_likes': 0, 'can_like': 1, ...              0
# 975  {'count': 42, 'user_likes': 0, 'can_like': 1, ...              0
# 976  {'count': 54, 'user_likes': 0, 'can_like': 1, ...              0
# 977  {'count': 15, 'user_likes': 0, 'can_like': 1, ...              0
# 978  {'count': 20, 'user_likes': 0, 'can_like': 1, ...              0
# 979  {'count': 27, 'user_likes': 0, 'can_like': 1, ...              0
# 980  {'count': 19, 'user_likes': 0, 'can_like': 1, ...              0
# 981  {'count': 53, 'user_likes': 0, 'can_like': 1, ...              0
# 982  {'count': 58, 'user_likes': 0, 'can_like': 1, ...              0
# 983  {'count': 27, 'user_likes': 0, 'can_like': 1, ...              0
# 984  {'count': 35, 'user_likes': 0, 'can_like': 1, ...              0
# 985  {'count': 20, 'user_likes': 0, 'can_like': 1, ...              0
# 986  {'count': 52, 'user_likes': 0, 'can_like': 1, ...              0
# 987  {'count': 38, 'user_likes': 0, 'can_like': 1, ...              0
# 988  {'count': 182, 'user_likes': 0, 'can_like': 1,...              0
# 989  {'count': 20, 'user_likes': 0, 'can_like': 1, ...              0
# 990  {'count': 58, 'user_likes': 0, 'can_like': 1, ...              0
# 991  {'count': 61, 'user_likes': 0, 'can_like': 1, ...              0
# 992  {'count': 88, 'user_likes': 0, 'can_like': 1, ...              0
# 993  {'count': 24, 'user_likes': 0, 'can_like': 1, ...              0
# 994  {'count': 68, 'user_likes': 0, 'can_like': 1, ...              0
# 995  {'count': 73, 'user_likes': 0, 'can_like': 1, ...              0
# 996  {'count': 49, 'user_likes': 0, 'can_like': 1, ...              0
# 997  {'count': 89, 'user_likes': 0, 'can_like': 1, ...              0
# 998  {'count': 42, 'user_likes': 0, 'can_like': 1, ...              0
# 999  {'count': 62, 'user_likes': 0, 'can_like': 1, ...              0
#
#      owner_id  ...             views  \
# 0   -66669811  ...   {'count': 7308}
# 1   -66669811  ...   {'count': 7647}
# 2   -66669811  ...   {'count': 8218}
# 3   -66669811  ...  {'count': 11238}
# 4   -66669811  ...   {'count': 9285}
# 5   -66669811  ...  {'count': 15322}
# 6   -66669811  ...  {'count': 18387}
# 7   -66669811  ...   {'count': 9721}
# 8   -66669811  ...  {'count': 22106}
# 9   -66669811  ...  {'count': 12101}
# 10  -66669811  ...  {'count': 15106}
# 11  -66669811  ...  {'count': 32263}
# 12  -66669811  ...  {'count': 18087}
# 13  -66669811  ...  {'count': 14108}
# 14  -66669811  ...  {'count': 21537}
# 15  -66669811  ...  {'count': 64798}
# 16  -66669811  ...  {'count': 17192}
# 17  -66669811  ...  {'count': 52539}
# 18  -66669811  ...  {'count': 14411}
# 19  -66669811  ...  {'count': 20081}
# 20  -66669811  ...  {'count': 17120}
# 21  -66669811  ...  {'count': 17067}
# 22  -66669811  ...  {'count': 19070}
# 23  -66669811  ...  {'count': 54463}
# 24  -66669811  ...  {'count': 37529}
# 25  -66669811  ...  {'count': 20370}
# 26  -66669811  ...  {'count': 18315}
# 27  -66669811  ...  {'count': 16426}
# 28  -66669811  ...  {'count': 33781}
# 29  -66669811  ...  {'count': 32498}
# ..        ...  ...               ...
# 970 -66669811  ...   {'count': 8588}
# 971 -66669811  ...  {'count': 13515}
# 972 -66669811  ...   {'count': 7019}
# 973 -66669811  ...   {'count': 7236}
# 974 -66669811  ...   {'count': 6921}
# 975 -66669811  ...   {'count': 8437}
# 976 -66669811  ...   {'count': 9050}
# 977 -66669811  ...   {'count': 6580}
# 978 -66669811  ...   {'count': 9642}
# 979 -66669811  ...   {'count': 7561}
# 980 -66669811  ...   {'count': 6170}
# 981 -66669811  ...   {'count': 7787}
# 982 -66669811  ...   {'count': 9099}
# 983 -66669811  ...   {'count': 6569}
# 984 -66669811  ...   {'count': 7441}
# 985 -66669811  ...   {'count': 6677}
# 986 -66669811  ...   {'count': 7546}
# 987 -66669811  ...   {'count': 9497}
# 988 -66669811  ...  {'count': 15434}
# 989 -66669811  ...   {'count': 6673}
# 990 -66669811  ...   {'count': 5631}
# 991 -66669811  ...  {'count': 12667}
# 992 -66669811  ...  {'count': 13629}
# 993 -66669811  ...   {'count': 8607}
# 994 -66669811  ...  {'count': 16711}
# 995 -66669811  ...  {'count': 11554}
# 996 -66669811  ...  {'count': 10405}
# 997 -66669811  ...  {'count': 10190}
# 998 -66669811  ...   {'count': 8395}
# 999 -66669811  ...  {'count': 10444}
#
#                                                   tags comments_count  \
# 0         [#В_закладки_Skillbox, #Skillbox_управление]              2
# 1             [#Статья_Skillbox, #Skillbox_управление]              0
# 2         [#Skillbox_программирование, #Skillbox_игра]              0
# 3                [#Skillbox_маркетинг, #Кейс_Skillbox]             11
# 4                 [#Статья_Skillbox, #Skillbox_дизайн]              0
# 5                                     [#Skillbox_игра]              9
# 6       [#Статья_Skillbox, #Skillbox_программирование]              1
# 7    [#Avocard, #Skillbox_маркетинг, #skillbox_в_за...              9
# 8         [#Уроки_Фотошопа_Skillbox, #Skillbox_дизайн]             18
# 9                 [#Статья_Skillbox, #Skillbox_дизайн]              2
# 10     [#Задачка_Skillbox, #Skillbox_программирование]             44
# 11                                                  []             15
# 12                              [#Расписание_Skillbox]             11
# 13                                                  []             44
# 14                              [#В_закладки_Skillbox]             13
# 15        [#Skillbox_управление, #В_закладки_Skillbox]             17
# 16             [#Статья_Skillbox, #Skillbox_маркетинг]              4
# 17       [#Дизайн_упаковки_Skillbox, #Skillbox_дизайн]             37
# 18            [#Статья_Skillbox, #Skillbox_управление]              2
# 19                                                  []              0
# 20      [#Статья_Skillbox, #Skillbox_программирование]              3
# 21                               [#Вам_слово_Skillbox]             28
# 22                [#Статья_Skillbox, #Skillbox_дизайн]              8
# 23                                                  []              0
# 24                                                  []              2
# 25                                                  []             56
# 26             [#Статья_Skillbox, #Skillbox_маркетинг]              5
# 27                [#skillbox_тренды, #Skillbox_дизайн]              6
# 28                                    [#Skillbox_игра]            171
# 29                  [#Skillbox_дизайн, #Кейс_Skillbox]             15
# ..                                                 ...            ...
# 970                                                 []              0
# 971                         [#collections, #marketing]              3
# 972                                 [#friday_typeface]              1
# 973                               [#read, #management]              0
# 974                                     [#read, #code]              6
# 975                              [#s2JsJK, #marketing]              0
# 976                                     [#read, #code]              2
# 977                                                 []              0
# 978                                          [#answer]             95
# 979                                                 []              2
# 980                                         [#reviews]              0
# 981                                                 []              0
# 982                                          [#design]              0
# 983                                         [#history]              0
# 984                                     [#read, #code]              2
# 985                                    [#designbattle]              6
# 986                                [#read, #marketing]              2
# 987                                        [#weekbook]              0
# 988                                   [#read, #design]              1
# 989                                                 []              0
# 990                                                 []              0
# 991                                                 []              6
# 992                                   [#y0fJdx, #code]              2
# 993                                                 []              5
# 994                                     [#collections]              0
# 995                                                 []              2
# 996                                 [#friday_typeface]              3
# 997                            [#collections, #design]              0
# 998                               [#read, #management]              0
# 999                                     [#read, #code]              0
#
#     likes_count reposts_count views_count  week_day  month  \
# 0            66            16        7308         5      1
# 1            32             2        7647         4      1
# 2            20             1        8218         4      1
# 3            42             2       11238         4      1
# 4            24             1        9285         3      1
# 5            40             0       15322         3      1
# 6            77            10       18387         2      1
# 7            25             4        9721         2      1
# 8           157            20       22106         2      1
# 9            32             6       12101         1      1
# 10           18             1       15106         1      1
# 11           61             7       32263         1      1
# 12           79            18       18087         0      1
# 13           22             1       14108         0      1
# 14           77             5       21537         6      1
# 15          419            77       64798         5      1
# 16           64            18       17192         4      1
# 17          233            17       52539         4      1
# 18           58            10       14411         3      1
# 19           91            17       20081         3      1
# 20           40             5       17120         2      1
# 21           26             0       17067         2      1
# 22          112            18       19070         0      1
# 23          359            71       54463         0      1
# 24           98             3       37529         5      1
# 25           31             0       20370         3      1
# 26           95            17       18315         0     12
# 27           63             8       16426         0     12
# 28          125            12       33781         0     12
# 29           58             6       32498         6     12
# ..          ...           ...         ...       ...    ...
# 970          36             1        8588         4      1
# 971         169            55       13515         4      1
# 972          26             1        7019         4      1
# 973          28             3        7236         4      1
# 974          18             1        6921         3      1
# 975          42             8        8437         3      1
# 976          54             6        9050         3      1
# 977          15             0        6580         3      1
# 978          20             0        9642         3      1
# 979          27             0        7561         2      1
# 980          19             0        6170         2      1
# 981          53             3        7787         2      1
# 982          58            12        9099         2      1
# 983          27             2        6569         2      1
# 984          35             5        7441         1      1
# 985          20             2        6677         1      1
# 986          52            12        7546         1      1
# 987          38             6        9497         1      1
# 988         182            36       15434         0      1
# 989          20             4        6673         0      1
# 990          58             3        5631         0      1
# 991          61             1       12667         6      1
# 992          88            18       13629         5      1
# 993          24             2        8607         5      1
# 994          68             5       16711         5      1
# 995          73             0       11554         4      1
# 996          49             7       10405         4      1
# 997          89            23       10190         4      1
# 998          42            12        8395         4      1
# 999          62             8       10444         3      1
#
#                date_full  time
# 0    2020-01-18 12:08:39    12
# 1    2020-01-17 19:15:34    19
# 2    2020-01-17 15:31:57    15
# 3    2020-01-17 11:00:03    11
# 4    2020-01-16 18:01:34    18
# 5    2020-01-16 12:04:12    12
# 6    2020-01-15 20:03:07    20
# 7    2020-01-15 16:40:16    16
# 8    2020-01-15 12:00:19    12
# 9    2020-01-14 18:01:10    18
# 10   2020-01-14 12:36:44    12
# 11   2020-01-14 10:35:15    10
# 12   2020-01-13 17:55:10    17
# 13   2020-01-13 11:40:04    11
# 14   2020-01-12 12:01:29    12
# 15   2020-01-11 12:23:07    12
# 16   2020-01-10 19:05:16    19
# 17   2020-01-10 12:00:32    12
# 18   2020-01-09 19:00:42    19
# 19   2020-01-09 12:01:41    12
# 20   2020-01-08 20:01:08    20
# 21   2020-01-08 12:10:27    12
# 22   2020-01-06 19:00:29    19
# 23   2020-01-06 13:42:49    13
# 24   2020-01-04 11:30:42    11
# 25   2020-01-02 12:40:13    12
# 26   2019-12-30 19:30:17    19
# 27   2019-12-30 15:50:46    15
# 28   2019-12-30 11:00:47    11
# 29   2019-12-29 12:02:19    12
# ..                   ...   ...
# 970  2019-01-18 19:30:01    19
# 971  2019-01-18 17:30:02    17
# 972  2019-01-18 15:30:02    15
# 973  2019-01-18 11:45:22    11
# 974  2019-01-17 19:30:02    19
# 975  2019-01-17 17:30:01    17
# 976  2019-01-17 15:30:02    15
# 977  2019-01-17 11:36:31    11
# 978  2019-01-17 10:30:05    10
# 979  2019-01-16 19:30:01    19
# 980  2019-01-16 17:30:01    17
# 981  2019-01-16 16:00:11    16
# 982  2019-01-16 15:30:01    15
# 983  2019-01-16 11:30:32    11
# 984  2019-01-15 19:30:01    19
# 985  2019-01-15 17:30:01    17
# 986  2019-01-15 15:30:02    15
# 987  2019-01-15 10:30:01    10
# 988  2019-01-14 17:30:01    17
# 989  2019-01-14 15:30:01    15
# 990  2019-01-14 13:00:07    13
# 991  2019-01-13 15:30:00    15
# 992  2019-01-12 15:30:00    15
# 993  2019-01-12 13:00:05    13
# 994  2019-01-12 10:30:01    10
# 995  2019-01-11 19:30:02    19
# 996  2019-01-11 17:30:03    17
# 997  2019-01-11 15:30:03    15
# 998  2019-01-11 12:23:00    12
# 999  2019-01-10 19:30:03    19
#
# [1000 rows x 24 columns]

# %%
#Проверим влияют ди временые факторы(время, месяц, день недели) на вовлеченность пользователей.
import seaborn as sns

ax = plt.axes()

sns.heatmap(df[['comments_count','likes_count','reposts_count','views_count','week_day','month','time']].corr(), ax=ax, center=0, annot=True)

ax.set_title('Занчения корреляций параметров публицай')
plt.show()

# %% [markdown]
# Наблюдаются только совсем очевидные корреляции между лайками, репостами и просмотрами.
# Зависимость вовлеченности от вермени дня, для недели или месяца не наблюдается.
# Проверим тоже самое но отдельно по нескольким категориям публикаций.

# %%
df['tags'] = df['tags'].apply(lambda x: set(x))
df_progr = df[df['tags']&{"#Skillbox_программирование"}]

# %%
ax = plt.axes()
sns.heatmap(df_progr[['comments_count','likes_count','reposts_count','views_count','week_day','month','time']].corr(), center=0, annot=True)
ax.set_title('Занчения корреляций параметров публицай #Skillbox_программирование')
plt.show()

# %%
#из диаграммы видно, что есть умеренная корреляция между днем недели и количеством лайков. Посмотри в какой день лайков больше.
import matplotlib.pyplot as plt

fig, subplot = plt.subplots()
fig.set_size_inches(10.5,6.5 , forward=True)
subplot.grid()
subplot.scatter(df_progr['week_day'], df_progr['comments_count'])

subplot.set_title("Зависисмоть количества лайков от дня недели.")
subplot.set_xlabel("День недели(0-понедельник)")
subplot.set_ylabel("Количество лайков")

plt.show()

# %% [markdown]
# По рубрике программирование наблюдается умеренная корреляция между днем недели и колличеством комментариев. Больше всего комментариев почему-то в среду. Возможно были какие-то более интересные статьи.

# %%
df['tags'] = df['tags'].apply(lambda x: set(x))
df_design = df[df['tags']&{"#Skillbox_дизайн"}]
df_design
# Out:
#                                            attachments  \
# 4    [{'type': 'link', 'link': {'url': 'https://ski...
# 8    [{'type': 'video', 'video': {'id': 456239765, ...
# 9    [{'type': 'link', 'link': {'url': 'https://ski...
# 17   [{'type': 'video', 'video': {'id': 456239758, ...
# 22   [{'type': 'link', 'link': {'url': 'https://ski...
# 27   [{'type': 'link', 'link': {'url': 'https://202...
# 29   [{'type': 'photo', 'photo': {'id': 457494559, ...
# 41   [{'type': 'video', 'video': {'id': 456239754, ...
# 42   [{'type': 'link', 'link': {'url': 'https://ski...
# 45   [{'type': 'photo', 'photo': {'id': 457494438, ...
# 49   [{'type': 'link', 'link': {'url': 'https://ski...
# 50   [{'type': 'photo', 'photo': {'id': 457494287, ...
# 52   [{'type': 'video', 'video': {'id': 456239749, ...
# 58   [{'type': 'video', 'video': {'id': 456239742, ...
# 63   [{'type': 'photo', 'photo': {'id': 457493760, ...
# 65   [{'type': 'link', 'link': {'url': 'https://ski...
# 71   [{'type': 'photo', 'photo': {'id': 457492320, ...
# 75   [{'type': 'link', 'link': {'url': 'https://ski...
# 76   [{'type': 'doc', 'doc': {'id': 595158964, 'own...
# 77   [{'type': 'photo', 'photo': {'id': 457492302, ...
# 97   [{'type': 'video', 'video': {'id': 456239706, ...
# 101  [{'type': 'photo', 'photo': {'id': 457491447, ...
# 105  [{'type': 'photo', 'photo': {'id': 457491375, ...
# 106  [{'type': 'link', 'link': {'url': 'https://ski...
# 108  [{'type': 'link', 'link': {'url': 'https://ski...
# 109  [{'type': 'doc', 'doc': {'id': 593228153, 'own...
# 110  [{'type': 'photo', 'photo': {'id': 457491273, ...
# 111  [{'type': 'photo', 'photo': {'id': 457491268, ...
# 115  [{'type': 'photo', 'photo': {'id': 457491122, ...
# 117  [{'type': 'photo', 'photo': {'id': 457491121, ...
# ..                                                 ...
# 385  [{'type': 'photo', 'photo': {'id': 457488381, ...
# 389  [{'type': 'photo', 'photo': {'id': 457488367, ...
# 390  [{'type': 'link', 'link': {'url': 'https://ski...
# 396  [{'type': 'link', 'link': {'url': 'https://ski...
# 397  [{'type': 'photo', 'photo': {'id': 457488345, ...
# 399  [{'type': 'photo', 'photo': {'id': 457488343, ...
# 403  [{'type': 'link', 'link': {'url': 'https://ski...
# 404  [{'type': 'video', 'video': {'id': 456239606, ...
# 407  [{'type': 'photo', 'photo': {'id': 456488315, ...
# 411  [{'type': 'link', 'link': {'url': 'https://ski...
# 412  [{'type': 'photo', 'photo': {'id': 456488302, ...
# 413  [{'type': 'link', 'link': {'url': 'https://ski...
# 415  [{'type': 'photo', 'photo': {'id': 456488295, ...
# 417  [{'type': 'link', 'link': {'url': 'https://ski...
# 419  [{'type': 'link', 'link': {'url': 'https://ski...
# 420  [{'type': 'photo', 'photo': {'id': 456488281, ...
# 421  [{'type': 'link', 'link': {'url': 'https://ski...
# 424  [{'type': 'photo', 'photo': {'id': 456488257, ...
# 426  [{'type': 'link', 'link': {'url': 'https://ski...
# 428  [{'type': 'link', 'link': {'url': 'https://ski...
# 429  [{'type': 'photo', 'photo': {'id': 456488247, ...
# 430  [{'type': 'photo', 'photo': {'id': 456488245, ...
# 433  [{'type': 'photo', 'photo': {'id': 456488229, ...
# 434  [{'type': 'link', 'link': {'url': 'https://ski...
# 437  [{'type': 'link', 'link': {'url': 'https://ski...
# 444  [{'type': 'photo', 'photo': {'id': 456468206, ...
# 448  [{'type': 'photo', 'photo': {'id': 456468184, ...
# 451  [{'type': 'photo', 'photo': {'id': 456468174, ...
# 453  [{'type': 'photo', 'photo': {'id': 456468169, ...
# 454  [{'type': 'photo', 'photo': {'id': 456468168, ...
#
#                                               comments copy_history  \
# 4    {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 8    {'count': 18, 'can_post': 1, 'groups_can_post'...          NaN
# 9    {'count': 2, 'can_post': 1, 'groups_can_post':...          NaN
# 17   {'count': 37, 'can_post': 1, 'groups_can_post'...          NaN
# 22   {'count': 8, 'can_post': 1, 'groups_can_post':...          NaN
# 27   {'count': 6, 'can_post': 1, 'groups_can_post':...          NaN
# 29   {'count': 15, 'can_post': 1, 'groups_can_post'...          NaN
# 41   {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 42   {'count': 2, 'can_post': 1, 'groups_can_post':...          NaN
# 45   {'count': 4, 'can_post': 1, 'groups_can_post':...          NaN
# 49   {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 50   {'count': 31, 'can_post': 1, 'groups_can_post'...          NaN
# 52   {'count': 2, 'can_post': 1, 'groups_can_post':...          NaN
# 58   {'count': 19, 'can_post': 1, 'groups_can_post'...          NaN
# 63   {'count': 44, 'can_post': 1, 'groups_can_post'...          NaN
# 65   {'count': 10, 'can_post': 1, 'groups_can_post'...          NaN
# 71   {'count': 89, 'can_post': 1, 'groups_can_post'...          NaN
# 75   {'count': 4, 'can_post': 1, 'groups_can_post':...          NaN
# 76   {'count': 3, 'can_post': 1, 'groups_can_post':...          NaN
# 77   {'count': 5, 'can_post': 1, 'groups_can_post':...          NaN
# 97   {'count': 16, 'can_post': 1, 'groups_can_post'...          NaN
# 101  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 105  {'count': 6, 'can_post': 1, 'groups_can_post':...          NaN
# 106  {'count': 6, 'can_post': 1, 'groups_can_post':...          NaN
# 108  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 109  {'count': 35, 'can_post': 1, 'groups_can_post'...          NaN
# 110  {'count': 30, 'can_post': 1, 'groups_can_post'...          NaN
# 111  {'count': 8, 'can_post': 1, 'groups_can_post':...          NaN
# 115  {'count': 9, 'can_post': 1, 'groups_can_post':...          NaN
# 117  {'count': 7, 'can_post': 1, 'groups_can_post':...          NaN
# ..                                                 ...          ...
# 385  {'count': 1, 'can_post': 1, 'groups_can_post':...          NaN
# 389  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 390  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 396  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 397  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 399  {'count': 64, 'can_post': 1, 'groups_can_post'...          NaN
# 403  {'count': 3, 'can_post': 1, 'groups_can_post':...          NaN
# 404  {'count': 3, 'can_post': 1, 'groups_can_post':...          NaN
# 407  {'count': 2, 'can_post': 1, 'groups_can_post':...          NaN
# 411  {'count': 4, 'can_post': 1, 'groups_can_post':...          NaN
# 412  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 413  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 415  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 417  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 419  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 420  {'count': 10, 'can_post': 1, 'groups_can_post'...          NaN
# 421  {'count': 7, 'can_post': 1, 'groups_can_post':...          NaN
# 424  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 426  {'count': 4, 'can_post': 1, 'groups_can_post':...          NaN
# 428  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 429  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 430  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 433  {'count': 5, 'can_post': 1, 'groups_can_post':...          NaN
# 434  {'count': 15, 'can_post': 1, 'groups_can_post'...          NaN
# 437  {'count': 3, 'can_post': 1, 'groups_can_post':...          NaN
# 444  {'count': 4, 'can_post': 1, 'groups_can_post':...          NaN
# 448  {'count': 42, 'can_post': 1, 'groups_can_post'...          NaN
# 451  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 453  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 454  {'count': 19, 'can_post': 1, 'groups_can_post'...          NaN
#
#                    date   from_id     id  is_favorite  \
# 4   2020-01-16 18:01:34 -66669811  49380        False
# 8   2020-01-15 12:00:19 -66669811  49249        False
# 9   2020-01-14 18:01:10 -66669811  49142        False
# 17  2020-01-10 12:00:32 -66669811  48382        False
# 22  2020-01-06 19:00:29 -66669811  48213        False
# 27  2019-12-30 15:50:46 -66669811  48026        False
# 29  2019-12-29 12:02:19 -66669811  47932        False
# 41  2019-12-24 12:01:43 -66669811  47856        False
# 42  2019-12-23 20:08:53 -66669811  47853        False
# 45  2019-12-22 11:15:24 -66669811  47768        False
# 49  2019-12-19 19:05:19 -66669811  47216        False
# 50  2019-12-19 12:15:12 -66669811  47079        False
# 52  2019-12-18 14:19:59 -66669811  47048        False
# 58  2019-12-14 12:00:03 -66669811  46634        False
# 63  2019-12-11 13:29:57 -66669811  45592        False
# 65  2019-12-10 18:50:25 -66669811  45377        False
# 71  2019-12-07 11:00:01 -66669811  44293        False
# 75  2019-12-05 17:00:10 -66669811  44037        False
# 76  2019-12-05 12:22:09 -66669811  43979        False
# 77  2019-12-04 19:00:01 -66669811  43555        False
# 97  2019-11-26 11:43:14 -66669811  41588        False
# 101 2019-11-24 19:00:02 -66669811  41498        False
# 105 2019-11-21 19:00:12 -66669811  41449        False
# 106 2019-11-21 17:02:36 -66669811  41446        False
# 108 2019-11-20 19:29:28 -66669811  41430        False
# 109 2019-11-20 12:46:07 -66669811  41407        False
# 110 2019-11-19 14:10:00 -66669811  41347        False
# 111 2019-11-19 12:01:50 -66669811  41305        False
# 115 2019-11-17 18:30:00 -66669811  41224        False
# 117 2019-11-16 12:30:00 -66669811  41068        False
# ..                  ...       ...    ...          ...
# 385 2019-07-18 14:55:08 -66669811  35296        False
# 389 2019-07-16 16:29:42 -66669811  35185        False
# 390 2019-07-15 18:30:02 -66669811  35180        False
# 396 2019-07-11 18:43:43 -66669811  35136        False
# 397 2019-07-11 15:30:57 -66669811  35126        False
# 399 2019-07-10 20:00:08 -66669811  35070        False
# 403 2019-07-09 18:34:24 -66669811  35053        False
# 404 2019-07-09 15:30:01 -66669811  35052        False
# 407 2019-07-08 15:30:02 -66669811  35031        False
# 411 2019-07-05 16:57:37 -66669811  35008        False
# 412 2019-07-05 14:22:48 -66669811  35005        False
# 413 2019-07-05 11:30:00 -66669811  34999        False
# 415 2019-07-04 14:30:02 -66669811  34951        False
# 417 2019-07-03 18:30:02 -66669811  34937        False
# 419 2019-07-02 19:53:02 -66669811  34915        False
# 420 2019-07-02 14:10:00 -66669811  34903        False
# 421 2019-07-02 12:41:50 -66669811  34897        False
# 424 2019-06-30 15:30:00 -66669811  34869        False
# 426 2019-06-28 18:30:02 -66669811  34823        False
# 428 2019-06-27 18:30:02 -66669811  34770        False
# 429 2019-06-27 12:30:02 -66669811  34764        False
# 430 2019-06-27 10:44:45 -66669811  34758        False
# 433 2019-06-26 09:42:14 -66669811  34738        False
# 434 2019-06-25 19:24:11 -66669811  34700        False
# 437 2019-06-24 18:30:03 -66669811  34660        False
# 444 2019-06-20 15:30:02 -66669811  34543        False
# 448 2019-06-18 12:30:00 -66669811  34440        False
# 451 2019-06-17 12:30:00 -66669811  34416        False
# 453 2019-06-16 12:30:00 -66669811  34410        False
# 454 2019-06-15 18:00:04 -66669811  34395        False
#
#                                                  likes  marked_as_ads  \
# 4    {'count': 24, 'user_likes': 0, 'can_like': 1, ...              0
# 8    {'count': 157, 'user_likes': 0, 'can_like': 1,...              0
# 9    {'count': 32, 'user_likes': 0, 'can_like': 1, ...              0
# 17   {'count': 233, 'user_likes': 0, 'can_like': 1,...              0
# 22   {'count': 112, 'user_likes': 0, 'can_like': 1,...              0
# 27   {'count': 63, 'user_likes': 0, 'can_like': 1, ...              0
# 29   {'count': 58, 'user_likes': 0, 'can_like': 1, ...              0
# 41   {'count': 55, 'user_likes': 0, 'can_like': 1, ...              0
# 42   {'count': 78, 'user_likes': 0, 'can_like': 1, ...              0
# 45   {'count': 186, 'user_likes': 0, 'can_like': 1,...              0
# 49   {'count': 59, 'user_likes': 0, 'can_like': 1, ...              0
# 50   {'count': 17, 'user_likes': 0, 'can_like': 1, ...              0
# 52   {'count': 41, 'user_likes': 0, 'can_like': 1, ...              0
# 58   {'count': 114, 'user_likes': 0, 'can_like': 1,...              0
# 63   {'count': 81, 'user_likes': 0, 'can_like': 1, ...              0
# 65   {'count': 173, 'user_likes': 0, 'can_like': 1,...              0
# 71   {'count': 46, 'user_likes': 0, 'can_like': 1, ...              0
# 75   {'count': 68, 'user_likes': 0, 'can_like': 1, ...              0
# 76   {'count': 259, 'user_likes': 0, 'can_like': 1,...              0
# 77   {'count': 639, 'user_likes': 0, 'can_like': 1,...              0
# 97   {'count': 131, 'user_likes': 0, 'can_like': 1,...              0
# 101  {'count': 45, 'user_likes': 0, 'can_like': 1, ...              0
# 105  {'count': 31, 'user_likes': 0, 'can_like': 1, ...              0
# 106  {'count': 54, 'user_likes': 0, 'can_like': 1, ...              0
# 108  {'count': 58, 'user_likes': 0, 'can_like': 1, ...              0
# 109  {'count': 59, 'user_likes': 0, 'can_like': 1, ...              0
# 110  {'count': 27, 'user_likes': 0, 'can_like': 1, ...              0
# 111  {'count': 114, 'user_likes': 0, 'can_like': 1,...              0
# 115  {'count': 50, 'user_likes': 0, 'can_like': 1, ...              0
# 117  {'count': 107, 'user_likes': 0, 'can_like': 1,...              0
# ..                                                 ...            ...
# 385  {'count': 34, 'user_likes': 0, 'can_like': 1, ...              0
# 389  {'count': 27, 'user_likes': 0, 'can_like': 1, ...              0
# 390  {'count': 96, 'user_likes': 0, 'can_like': 1, ...              0
# 396  {'count': 137, 'user_likes': 0, 'can_like': 1,...              0
# 397  {'count': 27, 'user_likes': 0, 'can_like': 1, ...              0
# 399  {'count': 23, 'user_likes': 0, 'can_like': 1, ...              0
# 403  {'count': 36, 'user_likes': 0, 'can_like': 1, ...              0
# 404  {'count': 46, 'user_likes': 0, 'can_like': 1, ...              0
# 407  {'count': 48, 'user_likes': 0, 'can_like': 1, ...              0
# 411  {'count': 43, 'user_likes': 0, 'can_like': 1, ...              0
# 412  {'count': 22, 'user_likes': 0, 'can_like': 1, ...              0
# 413  {'count': 24, 'user_likes': 0, 'can_like': 1, ...              0
# 415  {'count': 42, 'user_likes': 0, 'can_like': 1, ...              0
# 417  {'count': 105, 'user_likes': 0, 'can_like': 1,...              0
# 419  {'count': 29, 'user_likes': 0, 'can_like': 1, ...              0
# 420  {'count': 23, 'user_likes': 0, 'can_like': 1, ...              0
# 421  {'count': 81, 'user_likes': 0, 'can_like': 1, ...              0
# 424  {'count': 21, 'user_likes': 0, 'can_like': 1, ...              0
# 426  {'count': 75, 'user_likes': 0, 'can_like': 1, ...              0
# 428  {'count': 98, 'user_likes': 0, 'can_like': 1, ...              0
# 429  {'count': 27, 'user_likes': 0, 'can_like': 1, ...              0
# 430  {'count': 51, 'user_likes': 0, 'can_like': 1, ...              0
# 433  {'count': 18, 'user_likes': 0, 'can_like': 1, ...              0
# 434  {'count': 30, 'user_likes': 0, 'can_like': 1, ...              0
# 437  {'count': 142, 'user_likes': 0, 'can_like': 1,...              0
# 444  {'count': 51, 'user_likes': 0, 'can_like': 1, ...              0
# 448  {'count': 20, 'user_likes': 0, 'can_like': 1, ...              0
# 451  {'count': 130, 'user_likes': 0, 'can_like': 1,...              0
# 453  {'count': 64, 'user_likes': 0, 'can_like': 1, ...              0
# 454  {'count': 87, 'user_likes': 0, 'can_like': 1, ...              0
#
#      owner_id  ...             views  \
# 4   -66669811  ...   {'count': 9285}
# 8   -66669811  ...  {'count': 22106}
# 9   -66669811  ...  {'count': 12101}
# 17  -66669811  ...  {'count': 52539}
# 22  -66669811  ...  {'count': 19070}
# 27  -66669811  ...  {'count': 16426}
# 29  -66669811  ...  {'count': 32498}
# 41  -66669811  ...  {'count': 10017}
# 42  -66669811  ...  {'count': 14237}
# 45  -66669811  ...  {'count': 34969}
# 49  -66669811  ...  {'count': 12323}
# 50  -66669811  ...  {'count': 17252}
# 52  -66669811  ...  {'count': 13414}
# 58  -66669811  ...  {'count': 31729}
# 63  -66669811  ...  {'count': 26631}
# 65  -66669811  ...  {'count': 20664}
# 71  -66669811  ...  {'count': 22766}
# 75  -66669811  ...  {'count': 17456}
# 76  -66669811  ...  {'count': 18252}
# 77  -66669811  ...  {'count': 48886}
# 97  -66669811  ...  {'count': 16423}
# 101 -66669811  ...  {'count': 10849}
# 105 -66669811  ...   {'count': 9668}
# 106 -66669811  ...  {'count': 11280}
# 108 -66669811  ...  {'count': 11758}
# 109 -66669811  ...  {'count': 10847}
# 110 -66669811  ...  {'count': 10021}
# 111 -66669811  ...  {'count': 13253}
# 115 -66669811  ...   {'count': 8537}
# 117 -66669811  ...  {'count': 11942}
# ..        ...  ...               ...
# 385 -66669811  ...   {'count': 7315}
# 389 -66669811  ...   {'count': 6921}
# 390 -66669811  ...  {'count': 10986}
# 396 -66669811  ...  {'count': 12629}
# 397 -66669811  ...   {'count': 7764}
# 399 -66669811  ...  {'count': 11521}
# 403 -66669811  ...   {'count': 7602}
# 404 -66669811  ...   {'count': 9166}
# 407 -66669811  ...   {'count': 7848}
# 411 -66669811  ...   {'count': 8267}
# 412 -66669811  ...   {'count': 7580}
# 413 -66669811  ...   {'count': 7042}
# 415 -66669811  ...   {'count': 8325}
# 417 -66669811  ...  {'count': 11900}
# 419 -66669811  ...   {'count': 7337}
# 420 -66669811  ...   {'count': 7635}
# 421 -66669811  ...  {'count': 11205}
# 424 -66669811  ...   {'count': 7512}
# 426 -66669811  ...  {'count': 12094}
# 428 -66669811  ...  {'count': 11490}
# 429 -66669811  ...   {'count': 8065}
# 430 -66669811  ...  {'count': 11970}
# 433 -66669811  ...   {'count': 7901}
# 434 -66669811  ...   {'count': 9083}
# 437 -66669811  ...  {'count': 16882}
# 444 -66669811  ...  {'count': 10443}
# 448 -66669811  ...   {'count': 9839}
# 451 -66669811  ...  {'count': 10305}
# 453 -66669811  ...   {'count': 8601}
# 454 -66669811  ...  {'count': 13019}
#
#                                                   tags comments_count  \
# 4                 {#Статья_Skillbox, #Skillbox_дизайн}              0
# 8         {#Уроки_Фотошопа_Skillbox, #Skillbox_дизайн}             18
# 9                 {#Статья_Skillbox, #Skillbox_дизайн}              2
# 17       {#Дизайн_упаковки_Skillbox, #Skillbox_дизайн}             37
# 22                {#Статья_Skillbox, #Skillbox_дизайн}              8
# 27                {#skillbox_тренды, #Skillbox_дизайн}              6
# 29                  {#Skillbox_дизайн, #Кейс_Skillbox}             15
# 41                 {#Уроки_фотошопа, #Skillbox_дизайн}              0
# 42                {#Статья_Skillbox, #Skillbox_дизайн}              2
# 45   {#191970, #В_закладки_Skillbox, #7FFFD4, #FF45...              4
# 49                {#Статья_Skillbox, #Skillbox_дизайн}              0
# 50         {#Design_Battle_Skillbox, #Skillbox_дизайн}             31
# 52           {#Skillbox_вдохновляет, #Skillbox_дизайн}              2
# 58           {#Skillbox_вдохновляет, #Skillbox_дизайн}             19
# 63                                  {#Skillbox_дизайн}             44
# 65                {#Статья_Skillbox, #Skillbox_дизайн}             10
# 71         {#Design_Battle_Skillbox, #Skillbox_дизайн}             89
# 75                {#Статья_Skillbox, #Skillbox_дизайн}              4
# 76                                  {#Skillbox_дизайн}              3
# 77            {#В_закладки_Skillbox, #Skillbox_дизайн}              5
# 97   {#Уроки_Skillbox, #Фотошопзаминуту, #Skillbox_...             16
# 101               {#Skillbox_дизайн, #Шрифты_Skillbox}              0
# 105                                 {#Skillbox_дизайн}              6
# 106               {#Статья_Skillbox, #Skillbox_дизайн}              6
# 108               {#Статья_Skillbox, #Skillbox_дизайн}              0
# 109              {#Конкурс_Skillbox, #Skillbox_дизайн}             35
# 110        {#Design_Battle_Skillbox, #Skillbox_дизайн}             30
# 111      {#Работа_cтудента_Skillbox, #Skillbox_дизайн}              8
# 115          {#Полезное_от_Skillbox, #Skillbox_дизайн}              9
# 117                                 {#Skillbox_дизайн}              7
# ..                                                 ...            ...
# 385          {#Полезное_от_Skillbox, #Skillbox_дизайн}              1
# 389                {#После_Skillbox, #Skillbox_дизайн}              0
# 390               {#Статья_Skillbox, #Skillbox_дизайн}              0
# 396               {#Статья_Skillbox, #Skillbox_дизайн}              0
# 397          {#Полезное_от_Skillbox, #Skillbox_дизайн}              0
# 399        {#Design_Battle_Skillbox, #Skillbox_дизайн}             64
# 403               {#Статья_Skillbox, #Skillbox_дизайн}              3
# 404      {#Работа_студента_Skillbox, #Skillbox_дизайн}              3
# 407              {#Skillbox_дизайн, #Вебинар_Skillbox}              2
# 411               {#Статья_Skillbox, #Skillbox_дизайн}              4
# 412                 {#Курс_Skillbox, #Skillbox_дизайн}              0
# 413               {#Статья_Skillbox, #Skillbox_дизайн}              0
# 415          {#Полезное_от_Skillbox, #Skillbox_дизайн}              0
# 417               {#Статья_Skillbox, #Skillbox_дизайн}              0
# 419               {#Статья_Skillbox, #Skillbox_дизайн}              0
# 420         {#Разбор_кейса_Skillbox, #Skillbox_дизайн}             10
# 421               {#Статья_Skillbox, #Skillbox_дизайн}              7
# 424         {#Разбор_кейса_Skillbox, #Skillbox_дизайн}              0
# 426               {#Статья_Skillbox, #Skillbox_дизайн}              4
# 428               {#Статья_Skillbox, #Skillbox_дизайн}              0
# 429          {#Полезное_от_Skillbox, #Skillbox_дизайн}              0
# 430      {#Работа_студента_Skillbox, #Skillbox_дизайн}              0
# 433                 {#Курс_Skillbox, #Skillbox_дизайн}              5
# 434               {#Статья_Skillbox, #Skillbox_дизайн}             15
# 437               {#Статья_Skillbox, #Skillbox_дизайн}              3
# 444          {#Полезное_от_Skillbox, #Skillbox_дизайн}              4
# 448        {#Design_Battle_Skillbox, #Skillbox_дизайн}             42
# 451          {#Полезное_от_Skillbox, #Skillbox_дизайн}              0
# 453              {#Skillbox_дизайн, #Вебинар_Skillbox}              0
# 454                {#Skillbox_дизайн, #Анонс_Skillbox}             19
#
#     likes_count reposts_count views_count  week_day  month  \
# 4            24             1        9285         3      1
# 8           157            20       22106         2      1
# 9            32             6       12101         1      1
# 17          233            17       52539         4      1
# 22          112            18       19070         0      1
# 27           63             8       16426         0     12
# 29           58             6       32498         6     12
# 41           55             3       10017         1     12
# 42           78            22       14237         0     12
# 45          186            30       34969         6     12
# 49           59             8       12323         3     12
# 50           17             0       17252         3     12
# 52           41             3       13414         2     12
# 58          114             2       31729         5     12
# 63           81             6       26631         2     12
# 65          173            28       20664         1     12
# 71           46             2       22766         5     12
# 75           68            12       17456         3     12
# 76          259            36       18252         3     12
# 77          639           135       48886         2     12
# 97          131             9       16423         1     11
# 101          45             6       10849         6     11
# 105          31             1        9668         3     11
# 106          54             3       11280         3     11
# 108          58             3       11758         2     11
# 109          59             2       10847         2     11
# 110          27             1       10021         1     11
# 111         114             3       13253         1     11
# 115          50            11        8537         6     11
# 117         107            17       11942         5     11
# ..          ...           ...         ...       ...    ...
# 385          34             6        7315         3      7
# 389          27             2        6921         1      7
# 390          96            17       10986         0      7
# 396         137            38       12629         3      7
# 397          27             3        7764         3      7
# 399          23             3       11521         2      7
# 403          36             2        7602         1      7
# 404          46             1        9166         1      7
# 407          48             4        7848         0      7
# 411          43             3        8267         4      7
# 412          22             2        7580         4      7
# 413          24             2        7042         4      7
# 415          42             7        8325         3      7
# 417         105            21       11900         2      7
# 419          29             1        7337         1      7
# 420          23             1        7635         1      7
# 421          81            14       11205         1      7
# 424          21             2        7512         6      6
# 426          75            17       12094         4      6
# 428          98            16       11490         3      6
# 429          27             0        8065         3      6
# 430          51             5       11970         3      6
# 433          18             0        7901         2      6
# 434          30             2        9083         1      6
# 437         142            32       16882         0      6
# 444          51             2       10443         3      6
# 448          20             0        9839         1      6
# 451         130            29       10305         0      6
# 453          64            12        8601         6      6
# 454          87             8       13019         5      6
#
#                date_full  time
# 4    2020-01-16 18:01:34    18
# 8    2020-01-15 12:00:19    12
# 9    2020-01-14 18:01:10    18
# 17   2020-01-10 12:00:32    12
# 22   2020-01-06 19:00:29    19
# 27   2019-12-30 15:50:46    15
# 29   2019-12-29 12:02:19    12
# 41   2019-12-24 12:01:43    12
# 42   2019-12-23 20:08:53    20
# 45   2019-12-22 11:15:24    11
# 49   2019-12-19 19:05:19    19
# 50   2019-12-19 12:15:12    12
# 52   2019-12-18 14:19:59    14
# 58   2019-12-14 12:00:03    12
# 63   2019-12-11 13:29:57    13
# 65   2019-12-10 18:50:25    18
# 71   2019-12-07 11:00:01    11
# 75   2019-12-05 17:00:10    17
# 76   2019-12-05 12:22:09    12
# 77   2019-12-04 19:00:01    19
# 97   2019-11-26 11:43:14    11
# 101  2019-11-24 19:00:02    19
# 105  2019-11-21 19:00:12    19
# 106  2019-11-21 17:02:36    17
# 108  2019-11-20 19:29:28    19
# 109  2019-11-20 12:46:07    12
# 110  2019-11-19 14:10:00    14
# 111  2019-11-19 12:01:50    12
# 115  2019-11-17 18:30:00    18
# 117  2019-11-16 12:30:00    12
# ..                   ...   ...
# 385  2019-07-18 14:55:08    14
# 389  2019-07-16 16:29:42    16
# 390  2019-07-15 18:30:02    18
# 396  2019-07-11 18:43:43    18
# 397  2019-07-11 15:30:57    15
# 399  2019-07-10 20:00:08    20
# 403  2019-07-09 18:34:24    18
# 404  2019-07-09 15:30:01    15
# 407  2019-07-08 15:30:02    15
# 411  2019-07-05 16:57:37    16
# 412  2019-07-05 14:22:48    14
# 413  2019-07-05 11:30:00    11
# 415  2019-07-04 14:30:02    14
# 417  2019-07-03 18:30:02    18
# 419  2019-07-02 19:53:02    19
# 420  2019-07-02 14:10:00    14
# 421  2019-07-02 12:41:50    12
# 424  2019-06-30 15:30:00    15
# 426  2019-06-28 18:30:02    18
# 428  2019-06-27 18:30:02    18
# 429  2019-06-27 12:30:02    12
# 430  2019-06-27 10:44:45    10
# 433  2019-06-26 09:42:14     9
# 434  2019-06-25 19:24:11    19
# 437  2019-06-24 18:30:03    18
# 444  2019-06-20 15:30:02    15
# 448  2019-06-18 12:30:00    12
# 451  2019-06-17 12:30:00    12
# 453  2019-06-16 12:30:00    12
# 454  2019-06-15 18:00:04    18
#
# [144 rows x 24 columns]

# %%
ax = plt.axes()
sns.heatmap(df_design[['comments_count','likes_count','reposts_count','views_count','week_day','month','time']].corr(), center=0, annot=True)
ax.set_title('Занчения корреляций параметров публицай #Skillbox_дизайн')
plt.show()

# %% [markdown]
# Значимых корреляций не наблюдается.

# %%
df['tags'] = df['tags'].apply(lambda x: set(x))
df_webinar = df[df['tags']&{"#Вебинар_Skillbox"}]
df_webinar
# Out:
#                                            attachments  \
# 219  [{'type': 'photo', 'photo': {'id': 457490028, ...
# 235  [{'type': 'photo', 'photo': {'id': 457489563, ...
# 236  [{'type': 'link', 'link': {'url': 'https://web...
# 263  [{'type': 'photo', 'photo': {'id': 457489365, ...
# 276  [{'type': 'photo', 'photo': {'id': 457489317, ...
# 292  [{'type': 'photo', 'photo': {'id': 457489137, ...
# 309  [{'type': 'photo', 'photo': {'id': 457488827, ...
# 339  [{'type': 'photo', 'photo': {'id': 457488612, ...
# 347  [{'type': 'photo', 'photo': {'id': 457488491, ...
# 376  [{'type': 'photo', 'photo': {'id': 457488399, ...
# 393  [{'type': 'photo', 'photo': {'id': 457488352, ...
# 407  [{'type': 'photo', 'photo': {'id': 456488315, ...
# 409  [{'type': 'photo', 'photo': {'id': 456488304, ...
# 425  [{'type': 'photo', 'photo': {'id': 456488249, ...
# 439  [{'type': 'photo', 'photo': {'id': 456468213, ...
# 440  [{'type': 'photo', 'photo': {'id': 456468212, ...
# 453  [{'type': 'photo', 'photo': {'id': 456468169, ...
#
#                                               comments copy_history  \
# 219  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 235  {'count': 6, 'can_post': 1, 'groups_can_post':...          NaN
# 236  {'count': 21, 'can_post': 1, 'groups_can_post'...          NaN
# 263  {'count': 1, 'can_post': 1, 'groups_can_post':...          NaN
# 276  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 292  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 309  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 339  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 347  {'count': 1, 'can_post': 1, 'groups_can_post':...          NaN
# 376  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 393  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 407  {'count': 2, 'can_post': 1, 'groups_can_post':...          NaN
# 409  {'count': 7, 'can_post': 1, 'groups_can_post':...          NaN
# 425  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 439  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
# 440  {'count': 12, 'can_post': 1, 'groups_can_post'...          NaN
# 453  {'count': 0, 'can_post': 1, 'groups_can_post':...          NaN
#
#                    date   from_id     id  is_favorite  \
# 219 2019-09-28 12:20:14 -66669811  37118        False
# 235 2019-09-21 10:15:00 -66669811  36908        False
# 236 2019-09-20 16:29:32 -66669811  36904        False
# 263 2019-09-07 11:40:09 -66669811  36556        False
# 276 2019-08-31 13:00:18 -66669811  36455        False
# 292 2019-08-24 13:55:08 -66669811  36323        False
# 309 2019-08-17 12:55:18 -66669811  36082        False
# 339 2019-08-07 16:35:17 -66669811  35821        False
# 347 2019-08-03 15:30:00 -66669811  35732        False
# 376 2019-07-21 15:30:00 -66669811  35378        False
# 393 2019-07-14 12:30:00 -66669811  35157        False
# 407 2019-07-08 15:30:02 -66669811  35031        False
# 409 2019-07-07 12:30:00 -66669811  35021        False
# 425 2019-06-30 12:30:00 -66669811  34866        False
# 439 2019-06-23 12:30:00 -66669811  34634        False
# 440 2019-06-22 12:30:00 -66669811  34613        False
# 453 2019-06-16 12:30:00 -66669811  34410        False
#
#                                                  likes  marked_as_ads  \
# 219  {'count': 62, 'user_likes': 0, 'can_like': 1, ...              0
# 235  {'count': 77, 'user_likes': 0, 'can_like': 1, ...              0
# 236  {'count': 97, 'user_likes': 0, 'can_like': 1, ...              0
# 263  {'count': 50, 'user_likes': 0, 'can_like': 1, ...              0
# 276  {'count': 64, 'user_likes': 0, 'can_like': 1, ...              0
# 292  {'count': 61, 'user_likes': 0, 'can_like': 1, ...              0
# 309  {'count': 25, 'user_likes': 0, 'can_like': 1, ...              0
# 339  {'count': 43, 'user_likes': 0, 'can_like': 1, ...              0
# 347  {'count': 46, 'user_likes': 0, 'can_like': 1, ...              0
# 376  {'count': 115, 'user_likes': 0, 'can_like': 1,...              0
# 393  {'count': 55, 'user_likes': 0, 'can_like': 1, ...              0
# 407  {'count': 48, 'user_likes': 0, 'can_like': 1, ...              0
# 409  {'count': 81, 'user_likes': 0, 'can_like': 1, ...              0
# 425  {'count': 51, 'user_likes': 0, 'can_like': 1, ...              0
# 439  {'count': 65, 'user_likes': 0, 'can_like': 1, ...              0
# 440  {'count': 18, 'user_likes': 0, 'can_like': 1, ...              0
# 453  {'count': 64, 'user_likes': 0, 'can_like': 1, ...              0
#
#      owner_id  ...             views  \
# 219 -66669811  ...  {'count': 10579}
# 235 -66669811  ...  {'count': 11645}
# 236 -66669811  ...  {'count': 10060}
# 263 -66669811  ...   {'count': 9234}
# 276 -66669811  ...  {'count': 10636}
# 292 -66669811  ...   {'count': 8305}
# 309 -66669811  ...   {'count': 6130}
# 339 -66669811  ...   {'count': 8454}
# 347 -66669811  ...   {'count': 9587}
# 376 -66669811  ...  {'count': 13293}
# 393 -66669811  ...   {'count': 7820}
# 407 -66669811  ...   {'count': 7848}
# 409 -66669811  ...  {'count': 11391}
# 425 -66669811  ...   {'count': 9986}
# 439 -66669811  ...  {'count': 13291}
# 440 -66669811  ...   {'count': 9410}
# 453 -66669811  ...   {'count': 8601}
#
#                                                 tags comments_count  \
# 219  {#Skillbox_программирование, #Вебинар_Skillbox}              0
# 235         {#Skillbox_маркетинг, #Вебинар_Skillbox}              6
# 236            {#Skillbox_дизайн, #Вебинар_Skillbox}             21
# 263  {#Skillbox_программирование, #Вебинар_Skillbox}              1
# 276         {#Skillbox_маркетинг, #Вебинар_Skillbox}              0
# 292            {#Skillbox_дизайн, #Вебинар_Skillbox}              0
# 309            {#Skillbox_дизайн, #Вебинар_Skillbox}              0
# 339            {#Skillbox_дизайн, #Вебинар_Skillbox}              0
# 347         {#Skillbox_маркетинг, #Вебинар_Skillbox}              1
# 376            {#Skillbox_дизайн, #Вебинар_Skillbox}              0
# 393  {#Skillbox_программирование, #Вебинар_Skillbox}              0
# 407            {#Skillbox_дизайн, #Вебинар_Skillbox}              2
# 409         {#Skillbox_маркетинг, #Вебинар_Skillbox}              7
# 425  {#Skillbox_программирование, #Вебинар_Skillbox}              0
# 439        {#Skillbox_управление, #Вебинар_Skillbox}              0
# 440  {#Skillbox_программирование, #Вебинар_Skillbox}             12
# 453            {#Skillbox_дизайн, #Вебинар_Skillbox}              0
#
#     likes_count reposts_count views_count  week_day  month  \
# 219          62             9       10579         5      9
# 235          77             9       11645         5      9
# 236          97            10       10060         4      9
# 263          50             7        9234         5      9
# 276          64             6       10636         5      8
# 292          61            15        8305         5      8
# 309          25             2        6130         5      8
# 339          43             4        8454         2      8
# 347          46            11        9587         5      8
# 376         115            41       13293         6      7
# 393          55             8        7820         6      7
# 407          48             4        7848         0      7
# 409          81            18       11391         6      7
# 425          51            11        9986         6      6
# 439          65            17       13291         6      6
# 440          18             2        9410         5      6
# 453          64            12        8601         6      6
#
#                date_full  time
# 219  2019-09-28 12:20:14    12
# 235  2019-09-21 10:15:00    10
# 236  2019-09-20 16:29:32    16
# 263  2019-09-07 11:40:09    11
# 276  2019-08-31 13:00:18    13
# 292  2019-08-24 13:55:08    13
# 309  2019-08-17 12:55:18    12
# 339  2019-08-07 16:35:17    16
# 347  2019-08-03 15:30:00    15
# 376  2019-07-21 15:30:00    15
# 393  2019-07-14 12:30:00    12
# 407  2019-07-08 15:30:02    15
# 409  2019-07-07 12:30:00    12
# 425  2019-06-30 12:30:00    12
# 439  2019-06-23 12:30:00    12
# 440  2019-06-22 12:30:00    12
# 453  2019-06-16 12:30:00    12
#
# [17 rows x 24 columns]

# %%
ax = plt.axes()
sns.heatmap(df_webinar[['comments_count','likes_count','reposts_count','views_count','week_day','month','time']].corr(), center=0, annot=True)
ax.set_title('Занчения корреляций параметров публицай #Вебинар_Skillbox')
plt.show()

# %%
#Есть умеренная корреляция между количество репостов и днем недели. ПРоверим  в какой день больше репостов
import matplotlib.pyplot as plt

fig, subplot = plt.subplots()
fig.set_size_inches(10.5,6.5 , forward=True)
subplot.grid()
subplot.scatter(df_webinar['week_day'],df_webinar['reposts_count'])

subplot.set_title("Зависисмоть количества репостов от дня недели.")
subplot.set_xlabel("День недели(0-понедельник)")
subplot.set_ylabel("Количество репостов")


plt.show()

# %% [markdown]
# Наблюдается умеренная корреляция между днем недели и количеством просмотров и репостов.
# Из графика видно, что вовлеченность аудитории по рубрике Вебинаров сильно возрастает в выходные.
