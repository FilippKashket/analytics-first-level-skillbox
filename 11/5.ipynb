# %%
import pandas as pd
df = pd.DataFrame([['Anna', 23, 3],
             ['Sam', 36, 12],
             ['Bill', 33, 10],
             ['Monica', 25, 7],
             ['Lisa', 27, 7],
             ['Peter', 32, None]])
df.columns = ['name', 'age', 'expr']
df.index = df['name']

# %%
df.head()
# Out:
#           name  age  expr
# name
# Anna      Anna   23   3.0
# Sam        Sam   36  12.0
# Bill      Bill   33  10.0
# Monica  Monica   25   7.0
# Lisa      Lisa   27   7.0

# %%
df.head(2)
# Out:
#       name  age  expr
# name
# Anna  Anna   23   3.0
# Sam    Sam   36  12.0

# %%
df.tail()
# Out:
#           name  age  expr
# name
# Sam        Sam   36  12.0
# Bill      Bill   33  10.0
# Monica  Monica   25   7.0
# Lisa      Lisa   27   7.0
# Peter    Peter   32   NaN

# %%
df.tail(2)
# Out:
#         name  age  expr
# name
# Lisa    Lisa   27   7.0
# Peter  Peter   32   NaN

# %%
df = df.dropna()

# %%
df
# Out:
#           name  age  expr
# name
# Anna      Anna   23   3.0
# Sam        Sam   36  12.0
# Bill      Bill   33  10.0
# Monica  Monica   25   7.0
# Lisa      Lisa   27   7.0

# %%
df[df['age'] > 30]
# Out:
#       name  age  expr
# name
# Sam    Sam   36  12.0
# Bill  Bill   33  10.0

# %%
df[(df['age'] > 30) & (df['expr'] > 7)]
# Out:
#       name  age  expr
# name
# Sam    Sam   36  12.0
# Bill  Bill   33  10.0

# %%
df[(df['age'] > 35) | (df['age'] < 25)]
# Out:
#       name  age  expr
# name
# Anna  Anna   23   3.0
# Sam    Sam   36  12.0

# %%
df['age_sq'] = df['age'] ** 2

# %%
df
# Out:
#           name  age  expr  age_sq
# name
# Anna      Anna   23   3.0     529
# Sam        Sam   36  12.0    1296
# Bill      Bill   33  10.0    1089
# Monica  Monica   25   7.0     625
# Lisa      Lisa   27   7.0     729

# %%
df['status'] = 'W'

# %%
df
# Out:
#           name  age  expr  age_sq status
# name
# Anna      Anna   23   3.0     529      W
# Sam        Sam   36  12.0    1296      W
# Bill      Bill   33  10.0    1089      W
# Monica  Monica   25   7.0     625      W
# Lisa      Lisa   27   7.0     729      W

# %%
df['gender'] = [0, 1, 1, 0, 0]
df
# Out:
#           name  age  expr  age_sq status  gender
# name
# Anna      Anna   23   3.0     529      W       0
# Sam        Sam   36  12.0    1296      W       1
# Bill      Bill   33  10.0    1089      W       1
# Monica  Monica   25   7.0     625      W       0
# Lisa      Lisa   27   7.0     729      W       0

# %%
df['no_work'] = df['age'] - df['expr']
df
# Out:
#           name  age  expr  age_sq status  gender  no_work
# name
# Anna      Anna   23   3.0     529      W       0     20.0
# Sam        Sam   36  12.0    1296      W       1     24.0
# Bill      Bill   33  10.0    1089      W       1     23.0
# Monica  Monica   25   7.0     625      W       0     18.0
# Lisa      Lisa   27   7.0     729      W       0     20.0
